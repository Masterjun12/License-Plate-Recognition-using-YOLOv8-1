# %%
import pandas as pd
import numpy as np

# test.csv 파일을 읽어옵니다.
df = pd.read_csv('test.csv')

# 조건에 맞는 데이터만 필터링합니다.
df = df[(df['license_number'] != 'unknown') & (df['license_number_score'].notna())]

# car_id 별로 데이터를 그룹화하고, 프레임 번호에서 빈 공백을 전부 보정합니다.
def interpolate_license_numbers(group):
    frames = group['frame_nmr'].values
    scores = group['license_number_score'].values
    
    # license_plate_bbox를 문자열에서 리스트로 변환 (공백으로 구분)
    license_plate_bboxes = group['license_plate_bbox'].apply(
        lambda x: list(map(float, x.strip('[]').split()))  # 공백으로 나누도록 수정
    ).values
    
    # 프레임을 0에서부터 연속된 정수로 만든 후, 보간(interpolation)을 합니다.
    full_frames = np.arange(frames.min(), frames.max() + 1)
    interpolated_df = pd.DataFrame({'frame_nmr': full_frames})

    # 점수 데이터 보간
    interpolated_df['license_number_score'] = np.interp(full_frames, frames, scores)
    
    # bbox 보간은 하지 않고 그대로 가져옵니다.
    license_plate_bboxes_dict = dict(zip(frames, license_plate_bboxes))
    
    # 프레임 간 공백이 있을 때, 그 사이의 bbox를 보간하여 채웁니다.
    interpolated_bboxes = []
    for frame in full_frames:
        print(f"처리 중인 프레임: {frame}")  # 디버깅: 현재 프레임을 출력
        if frame in license_plate_bboxes_dict:
            print(f"frame {frame}에 bbox 있음: {license_plate_bboxes_dict[frame]}")  # 디버깅: bbox 값 출력
            interpolated_bboxes.append(license_plate_bboxes_dict[frame])
        else:
            # 앞뒤 프레임의 bbox 차이를 계산하여 보간
            prev_frame = full_frames[full_frames < frame].max() if (full_frames < frame).any() else None
            next_frame = full_frames[full_frames > frame].min() if frame < full_frames.max() else None
            print(f"이전 프레임: {prev_frame}, 다음 프레임: {next_frame}")  # 디버깅: 이전 및 다음 프레임 출력
            
            # prev_frame이 없으면 바로 앞의 프레임을 사용
            if prev_frame is None:  # prev_frame이 없으면 그 전 프레임의 bbox를 사용
                prev_frame = frame - 1  # 바로 앞의 프레임을 사용
            prev_bbox = np.array(license_plate_bboxes_dict.get(prev_frame, []))  # 수정: .get() 사용하여 KeyError 방지
            
            if next_frame is not None and next_frame in license_plate_bboxes_dict:
                next_bbox = np.array(license_plate_bboxes_dict[next_frame])
                
                # 각 컴포넌트별 선형 보간 (x1, y1, x2, y2)
                interpolated_bbox = []
                for prev_val, next_val in zip(prev_bbox, next_bbox):
                    ratio = (frame - prev_frame) / (next_frame - prev_frame)
                    interpolated_bbox.append(prev_val + ratio * (next_val - prev_val))
            else:
                # next_frame이 없다면 이전 프레임의 bbox를 그대로 사용
                interpolated_bbox = prev_bbox
                print(f"bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: {prev_bbox}")  # 디버깅: 사용된 bbox 출력
                
            interpolated_bboxes.append(interpolated_bbox)  # tolist()는 필요 없음
    
    interpolated_df['license_plate_bbox'] = interpolated_bboxes
    
    # 가장 높은 점수의 license_number를 찾습니다.
    best_license_number = group.loc[group['license_number_score'].idxmax()]['license_number']
    print(f"가장 높은 점수의 license_number: {best_license_number}")  # 디버깅: 최고 점수의 license_number 출력

    # 모든 프레임에 대해 동일한 license_number를 할당합니다.
    interpolated_df['license_number'] = best_license_number
    
    return interpolated_df

# 각 car_id 별로 보간(interpolation)을 수행합니다.
interpolated_df_list = []
for car_id, group in df.groupby('car_id'):
    print(f"Processing car_id: {car_id}")  # 디버깅: 현재 car_id 출력
    interpolated_group = interpolate_license_numbers(group)
    interpolated_group['car_id'] = car_id  # car_id 추가
    interpolated_df_list.append(interpolated_group)

# 모든 car_id에 대한 보간된 데이터프레임을 합칩니다.
final_df = pd.concat(interpolated_df_list)

# 결과를 test2.csv 파일로 저장합니다.
final_df.to_csv('test-interpolated.csv', index=False)

print("Interpolation 완료 후 test2.csv 저장 완료.")
# Out:
# Processing car_id: 27.0
# 처리 중인 프레임: 462
# frame 462에 bbox 있음: [668.3450927734375, 348.2243347167969, 834.7011108398438, 415.2502746582031]
# 처리 중인 프레임: 463
# frame 463에 bbox 있음: [662.1337280273438, 348.9031677246094, 834.8660888671875, 415.0970764160156]
# 처리 중인 프레임: 464
# frame 464에 bbox 있음: [657.94921875, 348.33380126953125, 829.7493896484375, 413.2100830078125]
# 처리 중인 프레임: 465
# frame 465에 bbox 있음: [657.9093627929688, 348.2719421386719, 829.7589721679688, 413.28472900390625]
# 처리 중인 프레임: 466
# 이전 프레임: 465, 다음 프레임: 467
# 처리 중인 프레임: 467
# frame 467에 bbox 있음: [648.5001220703125, 344.9659423828125, 826.8666381835938, 412.1864318847656]
# 처리 중인 프레임: 468
# frame 468에 bbox 있음: [643.6536865234375, 343.0175476074219, 823.000732421875, 411.48773193359375]
# 처리 중인 프레임: 469
# frame 469에 bbox 있음: [640.4811401367188, 342.03387451171875, 820.3818969726562, 410.9256591796875]
# 처리 중인 프레임: 470
# frame 470에 bbox 있음: [637.4917602539062, 341.89654541015625, 821.1600952148438, 410.7203063964844]
# 처리 중인 프레임: 471
# frame 471에 bbox 있음: [637.6062622070312, 341.87017822265625, 821.0687866210938, 410.6767272949219]
# 처리 중인 프레임: 472
# frame 472에 bbox 있음: [635.8617553710938, 342.0754699707031, 820.9713745117188, 411.2620544433594]
# 처리 중인 프레임: 473
# frame 473에 bbox 있음: [634.5964965820312, 342.75762939453125, 822.0730590820312, 411.6666259765625]
# 처리 중인 프레임: 474
# frame 474에 bbox 있음: [633.0604248046875, 342.5303955078125, 821.6687622070312, 412.30181884765625]
# 처리 중인 프레임: 475
# frame 475에 bbox 있음: [631.6528930664062, 343.6943054199219, 821.39501953125, 412.24688720703125]
# 처리 중인 프레임: 476
# frame 476에 bbox 있음: [632.379150390625, 345.6158142089844, 822.1783447265625, 413.04632568359375]
# 처리 중인 프레임: 477
# frame 477에 bbox 있음: [630.8606567382812, 344.55267333984375, 822.0125122070312, 412.63604736328125]
# 처리 중인 프레임: 478
# frame 478에 bbox 있음: [631.6767578125, 346.453857421875, 821.8425903320312, 413.822021484375]
# 처리 중인 프레임: 479
# frame 479에 bbox 있음: [631.6937866210938, 347.2265625, 821.3435668945312, 413.9792175292969]
# 처리 중인 프레임: 480
# frame 480에 bbox 있음: [631.27392578125, 347.77838134765625, 820.1694946289062, 415.7867736816406]
# 처리 중인 프레임: 481
# frame 481에 bbox 있음: [631.2960815429688, 348.58111572265625, 819.9262084960938, 416.94921875]
# 처리 중인 프레임: 482
# frame 482에 bbox 있음: [630.6591796875, 348.90838623046875, 820.0433349609375, 417.7229919433594]
# 처리 중인 프레임: 483
# frame 483에 bbox 있음: [630.670166015625, 348.91290283203125, 820.0770874023438, 417.69189453125]
# 처리 중인 프레임: 484
# frame 484에 bbox 있음: [630.9505004882812, 348.86627197265625, 819.9488525390625, 417.947021484375]
# 처리 중인 프레임: 485
# frame 485에 bbox 있음: [631.17333984375, 348.1040954589844, 819.3515625, 418.8490905761719]
# 처리 중인 프레임: 486
# frame 486에 bbox 있음: [632.1163330078125, 349.6217956542969, 821.1362915039062, 419.1820983886719]
# 처리 중인 프레임: 487
# frame 487에 bbox 있음: [630.8106689453125, 346.10589599609375, 822.986083984375, 422.65167236328125]
# 가장 높은 점수의 license_number: 50루7604
# Processing car_id: 39.0
# 처리 중인 프레임: 515
# frame 515에 bbox 있음: [633.7775268554688, 363.9963684082031, 825.3704833984375, 436.6414489746094]
# 처리 중인 프레임: 516
# frame 516에 bbox 있음: [632.994873046875, 368.3365173339844, 827.2988891601562, 439.74224853515625]
# 처리 중인 프레임: 517
# frame 517에 bbox 있음: [630.1876831054688, 371.7996826171875, 827.233154296875, 442.7339172363281]
# 처리 중인 프레임: 518
# frame 518에 bbox 있음: [634.7947998046875, 377.34625244140625, 831.87158203125, 448.8736572265625]
# 처리 중인 프레임: 519
# frame 519에 bbox 있음: [634.2460327148438, 376.76861572265625, 832.4310302734375, 449.3367919921875]
# 처리 중인 프레임: 520
# 이전 프레임: 519, 다음 프레임: 521
# 처리 중인 프레임: 521
# frame 521에 bbox 있음: [638.1262817382812, 384.35760498046875, 835.2786865234375, 459.9397888183594]
# 처리 중인 프레임: 522
# frame 522에 bbox 있음: [640.5726928710938, 391.6814880371094, 835.6624145507812, 466.1069030761719]
# 처리 중인 프레임: 523
# frame 523에 bbox 있음: [642.5643920898438, 395.41387939453125, 836.9103393554688, 474.07415771484375]
# 처리 중인 프레임: 524
# frame 524에 bbox 있음: [641.717529296875, 407.57391357421875, 840.0218505859375, 481.7701721191406]
# 처리 중인 프레임: 525
# frame 525에 bbox 있음: [641.81494140625, 408.200439453125, 839.8320922851562, 481.1712646484375]
# 처리 중인 프레임: 526
# frame 526에 bbox 있음: [643.0537719726562, 413.1365661621094, 844.2313842773438, 487.58880615234375]
# 처리 중인 프레임: 527
# frame 527에 bbox 있음: [643.1741333007812, 419.3653564453125, 845.3375854492188, 493.37567138671875]
# 처리 중인 프레임: 528
# frame 528에 bbox 있음: [648.3643798828125, 431.1602783203125, 847.2689208984375, 503.32489013671875]
# 처리 중인 프레임: 529
# 이전 프레임: 528, 다음 프레임: 530
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [648.36437988 431.16027832 847.2689209  503.32489014]
# 처리 중인 프레임: 530
# 이전 프레임: 529, 다음 프레임: 531
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 531
# 이전 프레임: 530, 다음 프레임: 532
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 532
# 이전 프레임: 531, 다음 프레임: 533
# 처리 중인 프레임: 533
# frame 533에 bbox 있음: [657.9034423828125, 481.8327331542969, 857.0451049804688, 559.9364624023438]
# 처리 중인 프레임: 534
# 이전 프레임: 533, 다음 프레임: 535
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [657.90344238 481.83273315 857.04510498 559.9364624 ]
# 처리 중인 프레임: 535
# 이전 프레임: 534, 다음 프레임: 536
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 536
# 이전 프레임: 535, 다음 프레임: 537
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 537
# 이전 프레임: 536, 다음 프레임: 538
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 538
# 이전 프레임: 537, 다음 프레임: 539
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 539
# 이전 프레임: 538, 다음 프레임: 540
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 540
# 이전 프레임: 539, 다음 프레임: 541
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 541
# 이전 프레임: 540, 다음 프레임: 542
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 542
# 이전 프레임: 541, 다음 프레임: 543
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 543
# 이전 프레임: 542, 다음 프레임: 544
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 544
# 이전 프레임: 543, 다음 프레임: 545
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 545
# 이전 프레임: 544, 다음 프레임: 546
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 546
# 이전 프레임: 545, 다음 프레임: 547
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 547
# 이전 프레임: 546, 다음 프레임: 548
# 처리 중인 프레임: 548
# frame 548에 bbox 있음: [706.4548950195312, 761.140869140625, 913.10302734375, 833.9586181640625]
# 처리 중인 프레임: 549
# frame 549에 bbox 있음: [706.4573364257812, 761.1542358398438, 913.1085205078125, 833.9404907226562]
# 처리 중인 프레임: 550
# 이전 프레임: 549, 다음 프레임: 551
# 처리 중인 프레임: 551
# frame 551에 bbox 있음: [716.0358276367188, 764.47265625, 924.9895629882812, 839.4525146484375]
# 처리 중인 프레임: 552
# 이전 프레임: 551, 다음 프레임: 553
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [716.03582764 764.47265625 924.98956299 839.45251465]
# 처리 중인 프레임: 553
# 이전 프레임: 552, 다음 프레임: 554
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 554
# 이전 프레임: 553, 다음 프레임: 555
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 555
# 이전 프레임: 554, 다음 프레임: 556
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 556
# 이전 프레임: 555, 다음 프레임: 557
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 557
# 이전 프레임: 556, 다음 프레임: 558
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 558
# 이전 프레임: 557, 다음 프레임: 559
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 559
# 이전 프레임: 558, 다음 프레임: 560
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 560
# 이전 프레임: 559, 다음 프레임: 561
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 561
# 이전 프레임: 560, 다음 프레임: 562
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 562
# 이전 프레임: 561, 다음 프레임: 563
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 563
# 이전 프레임: 562, 다음 프레임: 564
# 처리 중인 프레임: 564
# frame 564에 bbox 있음: [803.2417602539062, 707.5125732421875, 1025.354736328125, 785.511474609375]
# 처리 중인 프레임: 565
# 이전 프레임: 564, 다음 프레임: 566
# 처리 중인 프레임: 566
# frame 566에 bbox 있음: [827.1179809570312, 708.05712890625, 1050.5684814453125, 785.1097412109375]
# 처리 중인 프레임: 567
# frame 567에 bbox 있음: [827.1123046875, 708.0731201171875, 1050.60791015625, 785.1266479492188]
# 처리 중인 프레임: 568
# frame 568에 bbox 있음: [835.3536987304688, 710.9342651367188, 1059.1055908203125, 786.1056518554688]
# 처리 중인 프레임: 569
# frame 569에 bbox 있음: [845.9353637695312, 710.9140014648438, 1070.4984130859375, 787.6886596679688]
# 처리 중인 프레임: 570
# frame 570에 bbox 있음: [856.7719116210938, 708.3243408203125, 1089.39599609375, 790.0532836914062]
# 처리 중인 프레임: 571
# frame 571에 bbox 있음: [870.6502075195312, 710.7495727539062, 1098.48974609375, 789.5911254882812]
# 처리 중인 프레임: 572
# frame 572에 bbox 있음: [878.8591918945312, 714.2086181640625, 1106.87890625, 790.8624267578125]
# 처리 중인 프레임: 573
# frame 573에 bbox 있음: [878.9813232421875, 714.3070678710938, 1106.8828125, 790.8305053710938]
# 처리 중인 프레임: 574
# frame 574에 bbox 있음: [892.6323852539062, 716.1832885742188, 1127.6129150390625, 794.829345703125]
# 처리 중인 프레임: 575
# 이전 프레임: 574, 다음 프레임: 576
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [ 892.63238525  716.18328857 1127.61291504  794.8293457 ]
# 처리 중인 프레임: 576
# 이전 프레임: 575, 다음 프레임: 577
# 처리 중인 프레임: 577
# frame 577에 bbox 있음: [924.9563598632812, 720.8377075195312, 1161.779052734375, 800.1112060546875]
# 처리 중인 프레임: 578
# frame 578에 bbox 있음: [936.7423095703125, 722.00634765625, 1174.864013671875, 806.6979370117188]
# 처리 중인 프레임: 579
# frame 579에 bbox 있음: [936.6432495117188, 722.09814453125, 1174.9586181640625, 806.5036010742188]
# 처리 중인 프레임: 580
# 이전 프레임: 579, 다음 프레임: 581
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [ 936.64324951  722.09814453 1174.95861816  806.50360107]
# 처리 중인 프레임: 581
# 이전 프레임: 580, 다음 프레임: 582
# 처리 중인 프레임: 582
# frame 582에 bbox 있음: [981.452880859375, 727.740478515625, 1226.256591796875, 810.4422607421875]
# 가장 높은 점수의 license_number: 50루7604
# Processing car_id: 54.0
# 처리 중인 프레임: 629
# frame 629에 bbox 있음: [886.5803833007812, 638.6082153320312, 1055.804931640625, 708.1578979492188]
# 처리 중인 프레임: 630
# frame 630에 bbox 있음: [886.9595947265625, 641.4811401367188, 1053.8909912109375, 709.4366455078125]
# 처리 중인 프레임: 631
# 이전 프레임: 630, 다음 프레임: 632
# 처리 중인 프레임: 632
# frame 632에 bbox 있음: [882.62548828125, 645.8060913085938, 1051.9449462890625, 710.7960815429688]
# 처리 중인 프레임: 633
# frame 633에 bbox 있음: [882.6192626953125, 645.779296875, 1051.951171875, 710.8115844726562]
# 처리 중인 프레임: 634
# frame 634에 bbox 있음: [881.8474731445312, 647.9150390625, 1051.880615234375, 711.5758666992188]
# 처리 중인 프레임: 635
# frame 635에 bbox 있음: [881.1981811523438, 648.7844848632812, 1050.4315185546875, 713.54541015625]
# 처리 중인 프레임: 636
# frame 636에 bbox 있음: [879.9151611328125, 651.1124267578125, 1050.4764404296875, 715.0960693359375]
# 처리 중인 프레임: 637
# frame 637에 bbox 있음: [879.1631469726562, 652.2654418945312, 1050.206298828125, 716.3369750976562]
# 처리 중인 프레임: 638
# frame 638에 bbox 있음: [878.4049072265625, 653.4818725585938, 1050.7786865234375, 717.2763671875]
# 처리 중인 프레임: 639
# frame 639에 bbox 있음: [878.407470703125, 653.4841918945312, 1050.7552490234375, 717.2645874023438]
# 처리 중인 프레임: 640
# frame 640에 bbox 있음: [878.4825439453125, 654.6192016601562, 1052.499755859375, 719.9996337890625]
# 처리 중인 프레임: 641
# frame 641에 bbox 있음: [877.11328125, 654.0556640625, 1053.38671875, 721.7037963867188]
# 처리 중인 프레임: 642
# frame 642에 bbox 있음: [879.7362670898438, 655.3409423828125, 1052.771240234375, 722.1307983398438]
# 처리 중인 프레임: 643
# frame 643에 bbox 있음: [878.9996337890625, 656.5343627929688, 1053.7646484375, 723.3847045898438]
# 처리 중인 프레임: 644
# frame 644에 bbox 있음: [878.971435546875, 656.8179931640625, 1055.0438232421875, 724.6282348632812]
# 처리 중인 프레임: 645
# frame 645에 bbox 있음: [878.75537109375, 657.0214233398438, 1054.857421875, 724.5137329101562]
# 처리 중인 프레임: 646
# frame 646에 bbox 있음: [878.8151245117188, 658.2149658203125, 1056.1497802734375, 726.4435424804688]
# 처리 중인 프레임: 647
# frame 647에 bbox 있음: [879.5051879882812, 659.3340454101562, 1057.5330810546875, 728.3587646484375]
# 처리 중인 프레임: 648
# frame 648에 bbox 있음: [878.47265625, 663.943359375, 1057.0821533203125, 729.3506469726562]
# 처리 중인 프레임: 649
# frame 649에 bbox 있음: [878.244873046875, 665.497802734375, 1059.1392822265625, 731.5371704101562]
# 처리 중인 프레임: 650
# frame 650에 bbox 있음: [875.4387817382812, 666.1096801757812, 1061.5081787109375, 736.0357055664062]
# 처리 중인 프레임: 651
# frame 651에 bbox 있음: [875.418701171875, 666.1565551757812, 1061.47119140625, 736.0052490234375]
# 처리 중인 프레임: 652
# frame 652에 bbox 있음: [875.0861206054688, 668.699951171875, 1062.250244140625, 739.9039306640625]
# 처리 중인 프레임: 653
# frame 653에 bbox 있음: [875.9619140625, 669.2020263671875, 1064.078369140625, 742.8763427734375]
# 처리 중인 프레임: 654
# frame 654에 bbox 있음: [884.7672729492188, 676.6632080078125, 1066.659423828125, 740.5961303710938]
# 처리 중인 프레임: 655
# frame 655에 bbox 있음: [880.130126953125, 676.2193603515625, 1069.5816650390625, 747.7390747070312]
# 처리 중인 프레임: 656
# frame 656에 bbox 있음: [882.952880859375, 677.259033203125, 1071.979736328125, 750.121826171875]
# 처리 중인 프레임: 657
# frame 657에 bbox 있음: [882.9786987304688, 677.3366088867188, 1071.928466796875, 750.0477905273438]
# 처리 중인 프레임: 658
# frame 658에 bbox 있음: [881.2637329101562, 678.4866943359375, 1075.8927001953125, 757.2396850585938]
# 처리 중인 프레임: 659
# frame 659에 bbox 있음: [883.7391357421875, 681.2274169921875, 1076.193603515625, 758.5211791992188]
# 처리 중인 프레임: 660
# frame 660에 bbox 있음: [887.3130493164062, 686.0345458984375, 1080.3411865234375, 762.7778930664062]
# 처리 중인 프레임: 661
# frame 661에 bbox 있음: [888.9515991210938, 687.8582153320312, 1084.140869140625, 765.0260620117188]
# 처리 중인 프레임: 662
# frame 662에 bbox 있음: [889.5115356445312, 690.5347290039062, 1087.1661376953125, 768.0234375]
# 처리 중인 프레임: 663
# frame 663에 bbox 있음: [889.5397338867188, 690.5037231445312, 1087.2115478515625, 768.0238647460938]
# 처리 중인 프레임: 664
# frame 664에 bbox 있음: [891.3259887695312, 695.0233764648438, 1092.4495849609375, 774.4314575195312]
# 처리 중인 프레임: 665
# frame 665에 bbox 있음: [896.195068359375, 699.250732421875, 1096.2843017578125, 776.5216064453125]
# 처리 중인 프레임: 666
# frame 666에 bbox 있음: [900.3565673828125, 704.5690307617188, 1102.3651123046875, 781.088623046875]
# 처리 중인 프레임: 667
# frame 667에 bbox 있음: [902.4556884765625, 708.7811279296875, 1111.2425537109375, 787.020263671875]
# 처리 중인 프레임: 668
# frame 668에 bbox 있음: [909.0728759765625, 715.0821533203125, 1114.7711181640625, 788.63818359375]
# 처리 중인 프레임: 669
# frame 669에 bbox 있음: [909.037353515625, 715.087646484375, 1114.7548828125, 788.583984375]
# 처리 중인 프레임: 670
# frame 670에 bbox 있음: [916.7649536132812, 718.8139038085938, 1126.1529541015625, 798.0850219726562]
# 처리 중인 프레임: 671
# frame 671에 bbox 있음: [922.8876342773438, 723.1055908203125, 1131.718994140625, 803.0055541992188]
# 처리 중인 프레임: 672
# frame 672에 bbox 있음: [926.85498046875, 729.6102905273438, 1138.3443603515625, 812.4407958984375]
# 처리 중인 프레임: 673
# frame 673에 bbox 있음: [934.65087890625, 738.03515625, 1147.45166015625, 821.760498046875]
# 처리 중인 프레임: 674
# frame 674에 bbox 있음: [940.3856201171875, 745.8651733398438, 1156.999755859375, 828.2353515625]
# 처리 중인 프레임: 675
# 이전 프레임: 674, 다음 프레임: 676
# 처리 중인 프레임: 676
# frame 676에 bbox 있음: [952.4036865234375, 753.4649047851562, 1169.014892578125, 834.7868041992188]
# 처리 중인 프레임: 677
# frame 677에 bbox 있음: [960.1402587890625, 757.2947998046875, 1179.1278076171875, 836.587890625]
# 처리 중인 프레임: 678
# frame 678에 bbox 있음: [969.3578491210938, 759.7811279296875, 1188.69384765625, 836.9666748046875]
# 처리 중인 프레임: 679
# frame 679에 bbox 있음: [983.6790161132812, 760.1270141601562, 1206.7510986328125, 840.2286987304688]
# 처리 중인 프레임: 680
# frame 680에 bbox 있음: [994.0955200195312, 761.3659057617188, 1216.574462890625, 840.2147827148438]
# 처리 중인 프레임: 681
# frame 681에 bbox 있음: [994.1707763671875, 761.621337890625, 1216.3948974609375, 840.0465087890625]
# 가장 높은 점수의 license_number: 45두7627
# Processing car_id: 59.0
# 처리 중인 프레임: 1182
# frame 1182에 bbox 있음: [904.0250854492188, 625.8165893554688, 1040.1968994140625, 677.9329223632812]
# 처리 중인 프레임: 1183
# 이전 프레임: 1182, 다음 프레임: 1184
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [ 904.02508545  625.81658936 1040.19689941  677.93292236]
# 처리 중인 프레임: 1184
# 이전 프레임: 1183, 다음 프레임: 1185
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1185
# 이전 프레임: 1184, 다음 프레임: 1186
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1186
# 이전 프레임: 1185, 다음 프레임: 1187
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1187
# 이전 프레임: 1186, 다음 프레임: 1188
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1188
# 이전 프레임: 1187, 다음 프레임: 1189
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1189
# 이전 프레임: 1188, 다음 프레임: 1190
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1190
# 이전 프레임: 1189, 다음 프레임: 1191
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1191
# 이전 프레임: 1190, 다음 프레임: 1192
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1192
# 이전 프레임: 1191, 다음 프레임: 1193
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1193
# 이전 프레임: 1192, 다음 프레임: 1194
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1194
# 이전 프레임: 1193, 다음 프레임: 1195
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1195
# 이전 프레임: 1194, 다음 프레임: 1196
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1196
# 이전 프레임: 1195, 다음 프레임: 1197
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1197
# 이전 프레임: 1196, 다음 프레임: 1198
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1198
# 이전 프레임: 1197, 다음 프레임: 1199
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1199
# 이전 프레임: 1198, 다음 프레임: 1200
# 처리 중인 프레임: 1200
# frame 1200에 bbox 있음: [862.0342407226562, 625.6339721679688, 1000.0340576171875, 677.527587890625]
# 처리 중인 프레임: 1201
# 이전 프레임: 1200, 다음 프레임: 1202
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [ 862.03424072  625.63397217 1000.03405762  677.52758789]
# 처리 중인 프레임: 1202
# 이전 프레임: 1201, 다음 프레임: 1203
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1203
# 이전 프레임: 1202, 다음 프레임: 1204
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1204
# 이전 프레임: 1203, 다음 프레임: 1205
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1205
# 이전 프레임: 1204, 다음 프레임: 1206
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1206
# 이전 프레임: 1205, 다음 프레임: 1207
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1207
# 이전 프레임: 1206, 다음 프레임: 1208
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1208
# 이전 프레임: 1207, 다음 프레임: 1209
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1209
# 이전 프레임: 1208, 다음 프레임: 1210
# 처리 중인 프레임: 1210
# frame 1210에 bbox 있음: [828.3587036132812, 626.92626953125, 977.3388061523438, 678.6119995117188]
# 처리 중인 프레임: 1211
# frame 1211에 bbox 있음: [829.0989990234375, 626.998779296875, 973.57763671875, 682.2354125976562]
# 처리 중인 프레임: 1212
# frame 1212에 bbox 있음: [821.6422119140625, 628.3355712890625, 975.3804931640625, 680.6526489257812]
# 처리 중인 프레임: 1213
# 이전 프레임: 1212, 다음 프레임: 1214
# 처리 중인 프레임: 1214
# frame 1214에 bbox 있음: [816.7708740234375, 628.1408081054688, 966.5136108398438, 684.1148681640625]
# 처리 중인 프레임: 1215
# frame 1215에 bbox 있음: [816.8148193359375, 628.1715698242188, 966.5804443359375, 684.1119384765625]
# 처리 중인 프레임: 1216
# frame 1216에 bbox 있음: [811.0420532226562, 628.2557373046875, 959.2875366210938, 683.4088745117188]
# 처리 중인 프레임: 1217
# 이전 프레임: 1216, 다음 프레임: 1218
# 처리 중인 프레임: 1218
# frame 1218에 bbox 있음: [803.688720703125, 630.0337524414062, 951.9226684570312, 684.9251098632812]
# 처리 중인 프레임: 1219
# frame 1219에 bbox 있음: [798.8734130859375, 631.5238647460938, 952.3641357421875, 685.6312866210938]
# 처리 중인 프레임: 1220
# frame 1220에 bbox 있음: [794.3479614257812, 630.1481323242188, 951.5476684570312, 687.6842651367188]
# 처리 중인 프레임: 1221
# frame 1221에 bbox 있음: [794.4681396484375, 630.0679321289062, 951.5695190429688, 687.7952270507812]
# 처리 중인 프레임: 1222
# frame 1222에 bbox 있음: [791.8350219726562, 631.1511840820312, 948.3469848632812, 687.4916381835938]
# 처리 중인 프레임: 1223
# frame 1223에 bbox 있음: [793.3050537109375, 632.7993774414062, 948.6268310546875, 689.29931640625]
# 처리 중인 프레임: 1224
# frame 1224에 bbox 있음: [786.573486328125, 633.0238647460938, 946.8358154296875, 687.8648071289062]
# 처리 중인 프레임: 1225
# frame 1225에 bbox 있음: [785.4052734375, 634.25634765625, 943.1270141601562, 688.4205322265625]
# 처리 중인 프레임: 1226
# 이전 프레임: 1225, 다음 프레임: 1227
# 처리 중인 프레임: 1227
# frame 1227에 bbox 있음: [782.7467651367188, 635.0364990234375, 936.8171997070312, 690.4683837890625]
# 처리 중인 프레임: 1228
# frame 1228에 bbox 있음: [776.93701171875, 635.5697631835938, 932.62939453125, 690.64111328125]
# 처리 중인 프레임: 1229
# frame 1229에 bbox 있음: [774.1646118164062, 637.4660034179688, 929.0443725585938, 693.055908203125]
# 처리 중인 프레임: 1230
# frame 1230에 bbox 있음: [776.0593872070312, 636.8485717773438, 926.1209106445312, 692.7984008789062]
# 처리 중인 프레임: 1231
# frame 1231에 bbox 있음: [762.900390625, 634.9253540039062, 925.6778564453125, 696.6417846679688]
# 처리 중인 프레임: 1232
# frame 1232에 bbox 있음: [760.9118041992188, 636.972412109375, 923.6255493164062, 696.50439453125]
# 처리 중인 프레임: 1233
# frame 1233에 bbox 있음: [760.9898071289062, 636.9893188476562, 923.6112670898438, 696.4912719726562]
# 처리 중인 프레임: 1234
# 이전 프레임: 1233, 다음 프레임: 1235
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [760.98980713 636.98931885 923.61126709 696.49127197]
# 처리 중인 프레임: 1235
# 이전 프레임: 1234, 다음 프레임: 1236
# 처리 중인 프레임: 1236
# frame 1236에 bbox 있음: [756.6687622070312, 639.4458618164062, 912.9891967773438, 696.5614013671875]
# 처리 중인 프레임: 1237
# frame 1237에 bbox 있음: [751.8043823242188, 642.753173828125, 909.2512817382812, 699.1761474609375]
# 처리 중인 프레임: 1238
# frame 1238에 bbox 있음: [742.7272338867188, 641.4951782226562, 910.5368041992188, 697.9647216796875]
# 처리 중인 프레임: 1239
# frame 1239에 bbox 있음: [742.7298583984375, 641.4193725585938, 910.5950927734375, 697.9808349609375]
# 처리 중인 프레임: 1240
# frame 1240에 bbox 있음: [737.55859375, 641.6950073242188, 906.3424682617188, 703.0584106445312]
# 처리 중인 프레임: 1241
# 이전 프레임: 1240, 다음 프레임: 1242
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [737.55859375 641.69500732 906.34246826 703.05841064]
# 처리 중인 프레임: 1242
# 이전 프레임: 1241, 다음 프레임: 1243
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1243
# 이전 프레임: 1242, 다음 프레임: 1244
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1244
# 이전 프레임: 1243, 다음 프레임: 1245
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1245
# 이전 프레임: 1244, 다음 프레임: 1246
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1246
# 이전 프레임: 1245, 다음 프레임: 1247
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1247
# 이전 프레임: 1246, 다음 프레임: 1248
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1248
# 이전 프레임: 1247, 다음 프레임: 1249
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1249
# 이전 프레임: 1248, 다음 프레임: 1250
# 처리 중인 프레임: 1250
# frame 1250에 bbox 있음: [718.28173828125, 655.1541748046875, 898.3460083007812, 711.026611328125]
# 처리 중인 프레임: 1251
# frame 1251에 bbox 있음: [718.4925537109375, 655.2134399414062, 898.2649536132812, 711.1162719726562]
# 처리 중인 프레임: 1252
# 이전 프레임: 1251, 다음 프레임: 1253
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [718.49255371 655.21343994 898.26495361 711.11627197]
# 처리 중인 프레임: 1253
# 이전 프레임: 1252, 다음 프레임: 1254
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1254
# 이전 프레임: 1253, 다음 프레임: 1255
# 처리 중인 프레임: 1255
# frame 1255에 bbox 있음: [710.3699951171875, 657.4847412109375, 903.0253295898438, 717.524658203125]
# 처리 중인 프레임: 1256
# 이전 프레임: 1255, 다음 프레임: 1257
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [710.36999512 657.48474121 903.02532959 717.5246582 ]
# 처리 중인 프레임: 1257
# 이전 프레임: 1256, 다음 프레임: 1258
# 처리 중인 프레임: 1258
# frame 1258에 bbox 있음: [719.3640747070312, 659.5057983398438, 903.43359375, 720.6914672851562]
# 처리 중인 프레임: 1259
# 이전 프레임: 1258, 다음 프레임: 1260
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [719.36407471 659.50579834 903.43359375 720.69146729]
# 처리 중인 프레임: 1260
# 이전 프레임: 1259, 다음 프레임: 1261
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1261
# 이전 프레임: 1260, 다음 프레임: 1262
# 처리 중인 프레임: 1262
# frame 1262에 bbox 있음: [724.50048828125, 665.9645385742188, 913.5851440429688, 728.5015869140625]
# 처리 중인 프레임: 1263
# frame 1263에 bbox 있음: [724.3013305664062, 665.9638061523438, 913.357177734375, 728.52099609375]
# 처리 중인 프레임: 1264
# 이전 프레임: 1263, 다음 프레임: 1265
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [724.30133057 665.96380615 913.35717773 728.52099609]
# 처리 중인 프레임: 1265
# 이전 프레임: 1264, 다음 프레임: 1266
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1266
# 이전 프레임: 1265, 다음 프레임: 1267
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1267
# 이전 프레임: 1266, 다음 프레임: 1268
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1268
# 이전 프레임: 1267, 다음 프레임: 1269
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1269
# 이전 프레임: 1268, 다음 프레임: 1270
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1270
# 이전 프레임: 1269, 다음 프레임: 1271
# 처리 중인 프레임: 1271
# frame 1271에 bbox 있음: [753.3575439453125, 676.3408813476562, 954.5132446289062, 747.3450317382812]
# 처리 중인 프레임: 1272
# frame 1272에 bbox 있음: [758.8189086914062, 680.8676147460938, 959.4761352539062, 748.0717163085938]
# 처리 중인 프레임: 1273
# 이전 프레임: 1272, 다음 프레임: 1274
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [758.81890869 680.86761475 959.47613525 748.07171631]
# 처리 중인 프레임: 1274
# 이전 프레임: 1273, 다음 프레임: 1275
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1275
# 이전 프레임: 1274, 다음 프레임: 1276
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1276
# 이전 프레임: 1275, 다음 프레임: 1277
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1277
# 이전 프레임: 1276, 다음 프레임: 1278
# 처리 중인 프레임: 1278
# frame 1278에 bbox 있음: [803.7097778320312, 700.9814453125, 1010.7529907226562, 769.8281860351562]
# 처리 중인 프레임: 1279
# 이전 프레임: 1278, 다음 프레임: 1280
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [ 803.70977783  700.98144531 1010.75299072  769.82818604]
# 처리 중인 프레임: 1280
# 이전 프레임: 1279, 다음 프레임: 1281
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1281
# 이전 프레임: 1280, 다음 프레임: 1282
# 처리 중인 프레임: 1282
# frame 1282에 bbox 있음: [840.7963256835938, 719.314697265625, 1057.2437744140625, 785.6856689453125]
# 가장 높은 점수의 license_number: 01디7778
# Processing car_id: 68.0
# 처리 중인 프레임: 1477
# frame 1477에 bbox 있음: [832.2982788085938, 665.4219970703125, 985.9468383789062, 722.2617797851562]
# 처리 중인 프레임: 1478
# frame 1478에 bbox 있음: [825.7805786132812, 667.3763427734375, 981.7763671875, 726.90380859375]
# 처리 중인 프레임: 1479
# frame 1479에 bbox 있음: [825.8157348632812, 667.4074096679688, 981.8237915039062, 726.9293212890625]
# 처리 중인 프레임: 1480
# frame 1480에 bbox 있음: [822.2286987304688, 668.9061279296875, 978.9332885742188, 730.4890747070312]
# 처리 중인 프레임: 1481
# 이전 프레임: 1480, 다음 프레임: 1482
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [822.22869873 668.90612793 978.93328857 730.48907471]
# 처리 중인 프레임: 1482
# 이전 프레임: 1481, 다음 프레임: 1483
# 처리 중인 프레임: 1483
# frame 1483에 bbox 있음: [802.9142456054688, 672.4160766601562, 965.7933349609375, 733.103271484375]
# 처리 중인 프레임: 1484
# frame 1484에 bbox 있음: [800.2298583984375, 673.2273559570312, 963.7349853515625, 735.2030639648438]
# 처리 중인 프레임: 1485
# frame 1485에 bbox 있음: [800.2313232421875, 673.2294311523438, 963.6778564453125, 735.1963500976562]
# 처리 중인 프레임: 1486
# frame 1486에 bbox 있음: [794.7667236328125, 673.6480102539062, 959.867431640625, 736.6857299804688]
# 가장 높은 점수의 license_number: 24로3610
# Processing car_id: 69.0
# 처리 중인 프레임: 1487
# frame 1487에 bbox 있음: [789.2916870117188, 674.4811401367188, 956.1333618164062, 737.0616455078125]
# 처리 중인 프레임: 1488
# frame 1488에 bbox 있음: [783.3388061523438, 675.5709838867188, 951.7346801757812, 741.1759643554688]
# 처리 중인 프레임: 1489
# frame 1489에 bbox 있음: [779.6737060546875, 676.7206420898438, 948.5548095703125, 741.3433227539062]
# 처리 중인 프레임: 1490
# frame 1490에 bbox 있음: [774.5797119140625, 679.5126953125, 941.2987060546875, 741.11083984375]
# 처리 중인 프레임: 1491
# frame 1491에 bbox 있음: [774.5328979492188, 679.51025390625, 941.2852172851562, 741.1761474609375]
# 처리 중인 프레임: 1492
# frame 1492에 bbox 있음: [766.371337890625, 680.3888549804688, 940.4427490234375, 744.0313720703125]
# 처리 중인 프레임: 1493
# frame 1493에 bbox 있음: [763.5609741210938, 680.2225952148438, 936.7838745117188, 746.7291870117188]
# 처리 중인 프레임: 1494
# frame 1494에 bbox 있음: [758.667724609375, 682.5406494140625, 932.9539184570312, 748.1229858398438]
# 처리 중인 프레임: 1495
# frame 1495에 bbox 있음: [754.1442260742188, 682.47314453125, 930.3356323242188, 751.5465087890625]
# 처리 중인 프레임: 1496
# frame 1496에 bbox 있음: [751.664794921875, 684.9082641601562, 926.2152099609375, 753.6255493164062]
# 처리 중인 프레임: 1497
# frame 1497에 bbox 있음: [751.7041625976562, 684.9208374023438, 926.1300659179688, 753.6044311523438]
# 처리 중인 프레임: 1498
# frame 1498에 bbox 있음: [744.7750854492188, 688.5472412109375, 924.56689453125, 754.358642578125]
# 처리 중인 프레임: 1499
# frame 1499에 bbox 있음: [742.5410766601562, 691.383544921875, 923.1167602539062, 759.5742797851562]
# 처리 중인 프레임: 1500
# frame 1500에 bbox 있음: [734.1060791015625, 694.338134765625, 920.8487548828125, 762.5980224609375]
# 처리 중인 프레임: 1501
# frame 1501에 bbox 있음: [734.9927368164062, 697.9465942382812, 918.7456665039062, 764.6028442382812]
# 처리 중인 프레임: 1502
# frame 1502에 bbox 있음: [732.7017822265625, 700.4352416992188, 920.3724975585938, 767.0863647460938]
# 처리 중인 프레임: 1503
# frame 1503에 bbox 있음: [733.151611328125, 700.1002807617188, 920.0631103515625, 767.321044921875]
# 처리 중인 프레임: 1504
# frame 1504에 bbox 있음: [733.1923828125, 702.4402465820312, 921.333984375, 770.927734375]
# 처리 중인 프레임: 1505
# frame 1505에 bbox 있음: [731.8890991210938, 703.7107543945312, 920.5966796875, 774.2887573242188]
# 처리 중인 프레임: 1506
# frame 1506에 bbox 있음: [729.5980224609375, 706.8751831054688, 922.5803833007812, 777.8823852539062]
# 처리 중인 프레임: 1507
# frame 1507에 bbox 있음: [730.3751220703125, 710.8952026367188, 924.0730590820312, 781.54541015625]
# 처리 중인 프레임: 1508
# frame 1508에 bbox 있음: [729.2843627929688, 716.1180419921875, 929.10205078125, 789.0612182617188]
# 처리 중인 프레임: 1509
# frame 1509에 bbox 있음: [729.2974853515625, 716.1392211914062, 929.1216430664062, 789.0906372070312]
# 처리 중인 프레임: 1510
# frame 1510에 bbox 있음: [731.4043579101562, 719.1249389648438, 932.447021484375, 793.48095703125]
# 처리 중인 프레임: 1511
# frame 1511에 bbox 있음: [736.2872924804688, 721.28173828125, 936.76708984375, 796.5501708984375]
# 처리 중인 프레임: 1512
# frame 1512에 bbox 있음: [738.20654296875, 727.4330444335938, 944.5067138671875, 804.4166259765625]
# 처리 중인 프레임: 1513
# frame 1513에 bbox 있음: [743.4243774414062, 732.2993774414062, 949.4440307617188, 808.57177734375]
# 처리 중인 프레임: 1514
# frame 1514에 bbox 있음: [751.5101928710938, 743.3675537109375, 958.301513671875, 818.43603515625]
# 처리 중인 프레임: 1515
# frame 1515에 bbox 있음: [751.4603271484375, 743.2646484375, 958.3239135742188, 818.517333984375]
# 처리 중인 프레임: 1516
# frame 1516에 bbox 있음: [754.6578979492188, 749.5283203125, 966.2490844726562, 822.7642822265625]
# 처리 중인 프레임: 1517
# frame 1517에 bbox 있음: [761.666748046875, 755.1729125976562, 975.198486328125, 827.8423461914062]
# 처리 중인 프레임: 1518
# frame 1518에 bbox 있음: [773.337890625, 765.38818359375, 989.9285888671875, 838.2271728515625]
# 처리 중인 프레임: 1519
# frame 1519에 bbox 있음: [785.3328247070312, 770.9525756835938, 1000.6668701171875, 847.3573608398438]
# 처리 중인 프레임: 1520
# frame 1520에 bbox 있음: [797.1765747070312, 784.834228515625, 1017.8633422851562, 861.8427124023438]
# 처리 중인 프레임: 1521
# frame 1521에 bbox 있음: [797.1637573242188, 784.8065185546875, 1017.8732299804688, 861.9268798828125]
# 처리 중인 프레임: 1522
# frame 1522에 bbox 있음: [804.9380493164062, 794.6398315429688, 1030.5206298828125, 871.6322021484375]
# 처리 중인 프레임: 1523
# frame 1523에 bbox 있음: [819.712158203125, 801.3507080078125, 1044.02294921875, 878.7473754882812]
# 가장 높은 점수의 license_number: 24로3610
# Processing car_id: 92.0
# 처리 중인 프레임: 1946
# frame 1946에 bbox 있음: [472.0542297363281, 756.838623046875, 688.0067138671875, 836.09765625]
# 처리 중인 프레임: 1947
# frame 1947에 bbox 있음: [472.00994873046875, 756.7937622070312, 687.9669799804688, 836.1718139648438]
# 처리 중인 프레임: 1948
# frame 1948에 bbox 있음: [465.1938171386719, 759.7767944335938, 683.194580078125, 844.0979614257812]
# 처리 중인 프레임: 1949
# frame 1949에 bbox 있음: [455.580322265625, 768.61083984375, 674.7850341796875, 848.95166015625]
# 처리 중인 프레임: 1950
# 이전 프레임: 1949, 다음 프레임: 1951
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [455.58032227 768.61083984 674.78503418 848.95166016]
# 처리 중인 프레임: 1951
# 이전 프레임: 1950, 다음 프레임: 1952
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1952
# 이전 프레임: 1951, 다음 프레임: 1953
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1953
# 이전 프레임: 1952, 다음 프레임: 1954
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1954
# 이전 프레임: 1953, 다음 프레임: 1955
# 처리 중인 프레임: 1955
# frame 1955에 bbox 있음: [417.1018981933594, 786.1909790039062, 641.6609497070312, 866.504150390625]
# 처리 중인 프레임: 1956
# 이전 프레임: 1955, 다음 프레임: 1957
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [417.10189819 786.190979   641.66094971 866.50415039]
# 처리 중인 프레임: 1957
# 이전 프레임: 1956, 다음 프레임: 1958
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1958
# 이전 프레임: 1957, 다음 프레임: 1959
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1959
# 이전 프레임: 1958, 다음 프레임: 1960
# 처리 중인 프레임: 1960
# frame 1960에 bbox 있음: [387.8373718261719, 779.0502319335938, 618.5234375, 862.2053833007812]
# 처리 중인 프레임: 1961
# 이전 프레임: 1960, 다음 프레임: 1962
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [387.83737183 779.05023193 618.5234375  862.2053833 ]
# 처리 중인 프레임: 1962
# 이전 프레임: 1961, 다음 프레임: 1963
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1963
# 이전 프레임: 1962, 다음 프레임: 1964
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1964
# 이전 프레임: 1963, 다음 프레임: 1965
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1965
# 이전 프레임: 1964, 다음 프레임: 1966
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1966
# 이전 프레임: 1965, 다음 프레임: 1967
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1967
# 이전 프레임: 1966, 다음 프레임: 1968
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1968
# 이전 프레임: 1967, 다음 프레임: 1969
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1969
# 이전 프레임: 1968, 다음 프레임: 1970
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1970
# 이전 프레임: 1969, 다음 프레임: 1971
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1971
# 이전 프레임: 1970, 다음 프레임: 1972
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1972
# 이전 프레임: 1971, 다음 프레임: 1973
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1973
# 이전 프레임: 1972, 다음 프레임: 1974
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1974
# 이전 프레임: 1973, 다음 프레임: 1975
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1975
# 이전 프레임: 1974, 다음 프레임: 1976
# 처리 중인 프레임: 1976
# frame 1976에 bbox 있음: [267.76611328125, 810.82470703125, 524.8829956054688, 902.86083984375]
# 처리 중인 프레임: 1977
# 이전 프레임: 1976, 다음 프레임: 1978
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [267.76611328 810.82470703 524.88299561 902.86083984]
# 처리 중인 프레임: 1978
# 이전 프레임: 1977, 다음 프레임: 1979
# 처리 중인 프레임: 1979
# frame 1979에 bbox 있음: [254.18316650390625, 813.0140991210938, 516.2010498046875, 904.5422973632812]
# 처리 중인 프레임: 1980
# 이전 프레임: 1979, 다음 프레임: 1981
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [254.1831665  813.01409912 516.2010498  904.54229736]
# 처리 중인 프레임: 1981
# 이전 프레임: 1980, 다음 프레임: 1982
# 처리 중인 프레임: 1982
# frame 1982에 bbox 있음: [227.1376190185547, 816.131103515625, 491.5313720703125, 914.6231689453125]
# 처리 중인 프레임: 1983
# frame 1983에 bbox 있음: [227.1339111328125, 816.1360473632812, 491.5683288574219, 914.624267578125]
# 처리 중인 프레임: 1984
# frame 1984에 bbox 있음: [218.09930419921875, 819.6058959960938, 489.15911865234375, 917.0670776367188]
# 처리 중인 프레임: 1985
# frame 1985에 bbox 있음: [211.92384338378906, 819.8472900390625, 489.4548645019531, 922.2742919921875]
# 처리 중인 프레임: 1986
# frame 1986에 bbox 있음: [209.28872680664062, 829.5853881835938, 478.7899475097656, 922.91845703125]
# 처리 중인 프레임: 1987
# frame 1987에 bbox 있음: [203.2437286376953, 830.765625, 475.4322509765625, 926.4510498046875]
# 처리 중인 프레임: 1988
# frame 1988에 bbox 있음: [197.52374267578125, 836.3018188476562, 470.4932861328125, 930.3912963867188]
# 처리 중인 프레임: 1989
# frame 1989에 bbox 있음: [197.49737548828125, 836.4181518554688, 470.55084228515625, 930.3637084960938]
# 처리 중인 프레임: 1990
# frame 1990에 bbox 있음: [196.08297729492188, 837.8551635742188, 467.37579345703125, 932.4183349609375]
# 처리 중인 프레임: 1991
# frame 1991에 bbox 있음: [190.40867614746094, 840.1390380859375, 465.8815612792969, 933.5548706054688]
# 처리 중인 프레임: 1992
# frame 1992에 bbox 있음: [180.7807159423828, 837.6622924804688, 465.0782165527344, 944.9910278320312]
# 처리 중인 프레임: 1993
# frame 1993에 bbox 있음: [175.27816772460938, 837.83935546875, 462.5058288574219, 948.8448486328125]
# 처리 중인 프레임: 1994
# frame 1994에 bbox 있음: [167.22198486328125, 843.0283813476562, 455.03082275390625, 946.5884399414062]
# 처리 중인 프레임: 1995
# frame 1995에 bbox 있음: [167.1920928955078, 842.9448852539062, 455.0105895996094, 946.6265258789062]
# 처리 중인 프레임: 1996
# frame 1996에 bbox 있음: [163.7523651123047, 840.9781494140625, 451.27606201171875, 950.761962890625]
# 처리 중인 프레임: 1997
# frame 1997에 bbox 있음: [160.67843627929688, 842.91796875, 449.95147705078125, 951.943359375]
# 처리 중인 프레임: 1998
# frame 1998에 bbox 있음: [153.23895263671875, 843.6996459960938, 449.7276306152344, 952.4833374023438]
# 처리 중인 프레임: 1999
# frame 1999에 bbox 있음: [152.1752471923828, 847.2731323242188, 445.87335205078125, 951.7908325195312]
# 처리 중인 프레임: 2000
# frame 2000에 bbox 있음: [143.99002075195312, 848.1747436523438, 446.478515625, 961.3602905273438]
# 처리 중인 프레임: 2001
# frame 2001에 bbox 있음: [143.97317504882812, 848.1011352539062, 446.5434265136719, 961.4236450195312]
# 처리 중인 프레임: 2002
# frame 2002에 bbox 있음: [143.045654296875, 852.7421264648438, 439.53094482421875, 963.5941772460938]
# 처리 중인 프레임: 2003
# frame 2003에 bbox 있음: [140.2440948486328, 853.2916259765625, 437.40594482421875, 966.385986328125]
# 처리 중인 프레임: 2004
# frame 2004에 bbox 있음: [135.1482696533203, 858.3026733398438, 437.8375244140625, 970.2482299804688]
# 처리 중인 프레임: 2005
# frame 2005에 bbox 있음: [132.63059997558594, 860.2298583984375, 431.7290954589844, 970.869140625]
# 처리 중인 프레임: 2006
# frame 2006에 bbox 있음: [125.60875701904297, 861.4376220703125, 428.5833740234375, 977.74658203125]
# 처리 중인 프레임: 2007
# frame 2007에 bbox 있음: [125.56620788574219, 861.438232421875, 428.545166015625, 977.7109375]
# 처리 중인 프레임: 2008
# frame 2008에 bbox 있음: [122.06442260742188, 863.7185668945312, 424.29473876953125, 975.9521484375]
# 처리 중인 프레임: 2009
# frame 2009에 bbox 있음: [117.98600769042969, 866.5396728515625, 422.4101257324219, 973.9557495117188]
# 처리 중인 프레임: 2010
# frame 2010에 bbox 있음: [110.82682800292969, 865.9087524414062, 420.11053466796875, 977.9130859375]
# 처리 중인 프레임: 2011
# frame 2011에 bbox 있음: [110.54759216308594, 867.174560546875, 416.90673828125, 979.730224609375]
# 처리 중인 프레임: 2012
# frame 2012에 bbox 있음: [105.09915161132812, 867.3718872070312, 413.7036437988281, 980.2194213867188]
# 처리 중인 프레임: 2013
# frame 2013에 bbox 있음: [105.07826232910156, 867.377197265625, 413.687255859375, 980.2977905273438]
# 처리 중인 프레임: 2014
# frame 2014에 bbox 있음: [104.29852294921875, 869.150390625, 411.8515625, 980.5001220703125]
# 처리 중인 프레임: 2015
# frame 2015에 bbox 있음: [101.59913635253906, 871.435546875, 408.7640075683594, 980.196533203125]
# 처리 중인 프레임: 2016
# frame 2016에 bbox 있음: [96.0715103149414, 869.5338134765625, 405.1094970703125, 982.7574462890625]
# 처리 중인 프레임: 2017
# frame 2017에 bbox 있음: [91.97122192382812, 870.5518798828125, 402.32977294921875, 987.6066284179688]
# 처리 중인 프레임: 2018
# frame 2018에 bbox 있음: [86.71177673339844, 876.0781860351562, 397.6035461425781, 985.5093383789062]
# 처리 중인 프레임: 2019
# frame 2019에 bbox 있음: [86.70285034179688, 876.0972900390625, 397.6082458496094, 985.4971313476562]
# 처리 중인 프레임: 2020
# frame 2020에 bbox 있음: [83.56292724609375, 880.509033203125, 394.9128112792969, 983.798828125]
# 처리 중인 프레임: 2021
# frame 2021에 bbox 있음: [79.64420318603516, 877.568359375, 392.58013916015625, 988.5725708007812]
# 처리 중인 프레임: 2022
# frame 2022에 bbox 있음: [69.66017150878906, 877.2850952148438, 388.33831787109375, 994.5850219726562]
# 처리 중인 프레임: 2023
# frame 2023에 bbox 있음: [68.41210174560547, 881.251708984375, 383.73443603515625, 990.4752197265625]
# 처리 중인 프레임: 2024
# frame 2024에 bbox 있음: [62.47914505004883, 883.4382934570312, 377.2196044921875, 993.1913452148438]
# 처리 중인 프레임: 2025
# frame 2025에 bbox 있음: [62.3609619140625, 883.1246337890625, 377.3068542480469, 993.3645629882812]
# 처리 중인 프레임: 2026
# frame 2026에 bbox 있음: [57.12199401855469, 884.199462890625, 375.9361267089844, 998.154052734375]
# 처리 중인 프레임: 2027
# frame 2027에 bbox 있음: [55.46772766113281, 883.8480834960938, 371.1730041503906, 997.2593994140625]
# 처리 중인 프레임: 2028
# frame 2028에 bbox 있음: [50.68949890136719, 885.6243896484375, 365.95269775390625, 999.2730102539062]
# 처리 중인 프레임: 2029
# frame 2029에 bbox 있음: [44.30394744873047, 887.0969848632812, 362.5909423828125, 998.7349243164062]
# 처리 중인 프레임: 2030
# frame 2030에 bbox 있음: [38.52008056640625, 885.989501953125, 357.8302917480469, 1003.716796875]
# 처리 중인 프레임: 2031
# frame 2031에 bbox 있음: [38.56475830078125, 886.0083618164062, 357.98712158203125, 1003.7173461914062]
# 처리 중인 프레임: 2032
# frame 2032에 bbox 있음: [34.21307373046875, 888.7428588867188, 354.9654235839844, 1002.9605712890625]
# 처리 중인 프레임: 2033
# frame 2033에 bbox 있음: [31.357566833496094, 890.1925048828125, 352.96551513671875, 1004.7643432617188]
# 처리 중인 프레임: 2034
# 이전 프레임: 2033, 다음 프레임: 2035
# 처리 중인 프레임: 2035
# frame 2035에 bbox 있음: [27.322998046875, 890.3314819335938, 347.5455627441406, 1006.9304809570312]
# 처리 중인 프레임: 2036
# frame 2036에 bbox 있음: [25.78447723388672, 889.4322509765625, 347.31951904296875, 1006.8539428710938]
# 처리 중인 프레임: 2037
# frame 2037에 bbox 있음: [25.895233154296875, 889.3636474609375, 347.41253662109375, 1006.89501953125]
# 처리 중인 프레임: 2038
# frame 2038에 bbox 있음: [24.598960876464844, 889.31103515625, 345.8536071777344, 1006.8286743164062]
# 처리 중인 프레임: 2039
# frame 2039에 bbox 있음: [24.72509765625, 890.7643432617188, 344.9819641113281, 1007.2941284179688]
# 처리 중인 프레임: 2040
# frame 2040에 bbox 있음: [24.086837768554688, 890.4896850585938, 344.5915832519531, 1007.0114135742188]
# 처리 중인 프레임: 2041
# frame 2041에 bbox 있음: [23.573318481445312, 890.764404296875, 344.58648681640625, 1006.8344116210938]
# 처리 중인 프레임: 2042
# frame 2042에 bbox 있음: [23.64965057373047, 889.6732788085938, 345.2265930175781, 1006.7518310546875]
# 처리 중인 프레임: 2043
# frame 2043에 bbox 있음: [23.491607666015625, 889.0929565429688, 345.28509521484375, 1006.9070434570312]
# 처리 중인 프레임: 2044
# frame 2044에 bbox 있음: [23.12175750732422, 888.746337890625, 345.62567138671875, 1006.764404296875]
# 처리 중인 프레임: 2045
# frame 2045에 bbox 있음: [24.45245361328125, 886.8565063476562, 345.2276916503906, 1006.8008422851562]
# 처리 중인 프레임: 2046
# frame 2046에 bbox 있음: [25.20000457763672, 883.672119140625, 345.8289794921875, 1005.756591796875]
# 처리 중인 프레임: 2047
# frame 2047에 bbox 있음: [25.332183837890625, 883.9171752929688, 346.8012390136719, 1004.7415161132812]
# 처리 중인 프레임: 2048
# frame 2048에 bbox 있음: [24.77094268798828, 882.10400390625, 347.35552978515625, 1000.7603759765625]
# 처리 중인 프레임: 2049
# frame 2049에 bbox 있음: [24.830406188964844, 881.1470947265625, 347.4992980957031, 1002.4114379882812]
# 처리 중인 프레임: 2050
# frame 2050에 bbox 있음: [22.968154907226562, 880.3342895507812, 346.3713684082031, 999.2741088867188]
# 처리 중인 프레임: 2051
# frame 2051에 bbox 있음: [22.925743103027344, 879.9087524414062, 344.4943542480469, 997.1603393554688]
# 처리 중인 프레임: 2052
# frame 2052에 bbox 있음: [22.860626220703125, 879.4376220703125, 343.356201171875, 995.4056396484375]
# 처리 중인 프레임: 2053
# frame 2053에 bbox 있음: [22.852340698242188, 879.90771484375, 343.7589111328125, 995.6891479492188]
# 처리 중인 프레임: 2054
# frame 2054에 bbox 있음: [21.598709106445312, 880.2344970703125, 343.5617370605469, 999.177978515625]
# 처리 중인 프레임: 2055
# frame 2055에 bbox 있음: [21.47845458984375, 880.1220703125, 343.5681457519531, 999.2259521484375]
# 처리 중인 프레임: 2056
# frame 2056에 bbox 있음: [20.033889770507812, 879.7614135742188, 343.2286376953125, 1000.8236083984375]
# 처리 중인 프레임: 2057
# frame 2057에 bbox 있음: [18.729515075683594, 879.591796875, 342.9967346191406, 1002.09375]
# 처리 중인 프레임: 2058
# frame 2058에 bbox 있음: [16.731468200683594, 881.8793334960938, 342.4200744628906, 1000.7971801757812]
# 처리 중인 프레임: 2059
# frame 2059에 bbox 있음: [15.2962646484375, 884.9007568359375, 340.6683654785156, 998.6185913085938]
# 처리 중인 프레임: 2060
# frame 2060에 bbox 있음: [15.208213806152344, 885.3538208007812, 338.6312561035156, 998.9932861328125]
# 처리 중인 프레임: 2061
# frame 2061에 bbox 있음: [15.256622314453125, 886.207275390625, 338.3805847167969, 997.732421875]
# 처리 중인 프레임: 2062
# frame 2062에 bbox 있음: [18.237327575683594, 883.9907836914062, 335.92913818359375, 1000.6758422851562]
# 처리 중인 프레임: 2063
# frame 2063에 bbox 있음: [15.800148010253906, 884.9067993164062, 334.5874328613281, 1000.4859008789062]
# 처리 중인 프레임: 2064
# frame 2064에 bbox 있음: [10.026901245117188, 883.3129272460938, 333.4974060058594, 1001.531494140625]
# 처리 중인 프레임: 2065
# frame 2065에 bbox 있음: [8.854087829589844, 888.3015747070312, 332.5309753417969, 998.2183227539062]
# 처리 중인 프레임: 2066
# 이전 프레임: 2065, 다음 프레임: 2067
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [  8.85408783 888.30157471 332.53097534 998.21832275]
# 처리 중인 프레임: 2067
# 이전 프레임: 2066, 다음 프레임: 2068
# 처리 중인 프레임: 2068
# frame 2068에 bbox 있음: [8.756904602050781, 884.3594970703125, 322.2251892089844, 1004.876953125]
# 처리 중인 프레임: 2069
# frame 2069에 bbox 있음: [6.7140655517578125, 886.0588989257812, 320.9169921875, 1004.2758178710938]
# 처리 중인 프레임: 2070
# frame 2070에 bbox 있음: [2.9341964721679688, 888.6222534179688, 314.6271057128906, 1004.058349609375]
# 처리 중인 프레임: 2071
# frame 2071에 bbox 있음: [4.153495788574219, 889.7171630859375, 311.22784423828125, 1005.94775390625]
# 처리 중인 프레임: 2072
# frame 2072에 bbox 있음: [2.8263931274414062, 890.098388671875, 307.5205383300781, 1005.607177734375]
# 처리 중인 프레임: 2073
# frame 2073에 bbox 있음: [2.8165512084960938, 890.1251220703125, 307.4458923339844, 1005.6388549804688]
# 처리 중인 프레임: 2074
# frame 2074에 bbox 있음: [2.9748687744140625, 891.7827758789062, 301.272216796875, 1006.0303344726562]
# 처리 중인 프레임: 2075
# frame 2075에 bbox 있음: [2.2696151733398438, 893.75537109375, 297.5453186035156, 1006.3388671875]
# 처리 중인 프레임: 2076
# frame 2076에 bbox 있음: [1.9373016357421875, 893.1965942382812, 288.6319274902344, 1008.4299926757812]
# 처리 중인 프레임: 2077
# frame 2077에 bbox 있음: [1.5483627319335938, 893.1551513671875, 281.8000793457031, 1010.2122802734375]
# 처리 중인 프레임: 2078
# frame 2078에 bbox 있음: [1.3658294677734375, 895.0902099609375, 273.2176208496094, 1009.70361328125]
# 처리 중인 프레임: 2079
# frame 2079에 bbox 있음: [1.366973876953125, 895.084716796875, 273.21514892578125, 1009.7127685546875]
# 처리 중인 프레임: 2080
# frame 2080에 bbox 있음: [0.7987289428710938, 897.3841552734375, 262.0469970703125, 1011.6925048828125]
# 처리 중인 프레임: 2081
# frame 2081에 bbox 있음: [0.652130126953125, 899.3794555664062, 256.2716064453125, 1011.2969970703125]
# 가장 높은 점수의 license_number: 229저9262
# Processing car_id: 94.0
# 처리 중인 프레임: 1993
# frame 1993에 bbox 있음: [967.77099609375, 648.5104370117188, 1113.4571533203125, 712.5975952148438]
# 처리 중인 프레임: 1994
# 이전 프레임: 1993, 다음 프레임: 1995
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [ 967.77099609  648.51043701 1113.45715332  712.59759521]
# 처리 중인 프레임: 1995
# 이전 프레임: 1994, 다음 프레임: 1996
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 1996
# 이전 프레임: 1995, 다음 프레임: 1997
# 처리 중인 프레임: 1997
# frame 1997에 bbox 있음: [967.4630737304688, 649.2030029296875, 1116.62353515625, 712.4505615234375]
# 처리 중인 프레임: 1998
# frame 1998에 bbox 있음: [957.3515625, 650.950927734375, 1118.0047607421875, 717.4288330078125]
# 처리 중인 프레임: 1999
# frame 1999에 bbox 있음: [958.956298828125, 652.175537109375, 1116.96728515625, 716.5816040039062]
# 처리 중인 프레임: 2000
# 이전 프레임: 1999, 다음 프레임: 2001
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [ 958.95629883  652.17553711 1116.96728516  716.581604  ]
# 처리 중인 프레임: 2001
# 이전 프레임: 2000, 다음 프레임: 2002
# 처리 중인 프레임: 2002
# frame 2002에 bbox 있음: [952.6840209960938, 657.0928955078125, 1116.3330078125, 715.3597412109375]
# 처리 중인 프레임: 2003
# frame 2003에 bbox 있음: [950.9177856445312, 657.5165405273438, 1116.353759765625, 717.1162109375]
# 처리 중인 프레임: 2004
# frame 2004에 bbox 있음: [945.1439208984375, 654.0504150390625, 1117.365234375, 723.7182006835938]
# 처리 중인 프레임: 2005
# frame 2005에 bbox 있음: [955.5286254882812, 658.6556396484375, 1115.5831298828125, 720.8607788085938]
# 처리 중인 프레임: 2006
# frame 2006에 bbox 있음: [947.9130859375, 660.4200439453125, 1110.3009033203125, 721.1092529296875]
# 처리 중인 프레임: 2007
# frame 2007에 bbox 있음: [947.9452514648438, 660.4390869140625, 1110.2325439453125, 721.1475219726562]
# 처리 중인 프레임: 2008
# frame 2008에 bbox 있음: [945.5870971679688, 661.6173706054688, 1110.383056640625, 722.8916015625]
# 처리 중인 프레임: 2009
# frame 2009에 bbox 있음: [945.6373901367188, 662.19140625, 1108.360595703125, 721.3128662109375]
# 처리 중인 프레임: 2010
# frame 2010에 bbox 있음: [951.9796142578125, 664.7510375976562, 1104.9873046875, 721.8046875]
# 가장 높은 점수의 license_number: 60리3516
# Processing car_id: 103.0
# 처리 중인 프레임: 2121
# frame 2121에 bbox 있음: [842.9296875, 707.0986938476562, 1034.0987548828125, 784.497802734375]
# 처리 중인 프레임: 2122
# frame 2122에 bbox 있음: [839.53564453125, 709.8855590820312, 1032.2501220703125, 786.41748046875]
# 처리 중인 프레임: 2123
# frame 2123에 bbox 있음: [837.6639404296875, 713.1549682617188, 1030.956298828125, 786.4927368164062]
# 처리 중인 프레임: 2124
# frame 2124에 bbox 있음: [834.6568603515625, 715.1397094726562, 1036.8343505859375, 785.6318359375]
# 처리 중인 프레임: 2125
# frame 2125에 bbox 있음: [833.1110229492188, 714.6643676757812, 1038.166015625, 788.6144409179688]
# 처리 중인 프레임: 2126
# frame 2126에 bbox 있음: [825.4686279296875, 715.1873168945312, 1039.8251953125, 791.4723510742188]
# 처리 중인 프레임: 2127
# frame 2127에 bbox 있음: [818.4486694335938, 714.3003540039062, 1040.1719970703125, 792.3182983398438]
# 처리 중인 프레임: 2128
# frame 2128에 bbox 있음: [836.6240844726562, 716.65283203125, 1042.133056640625, 794.9256591796875]
# 처리 중인 프레임: 2129
# frame 2129에 bbox 있음: [818.864501953125, 716.2285766601562, 1045.20556640625, 799.9129028320312]
# 처리 중인 프레임: 2130
# frame 2130에 bbox 있음: [841.7003784179688, 720.0826416015625, 1050.064453125, 799.4758911132812]
# 처리 중인 프레임: 2131
# 이전 프레임: 2130, 다음 프레임: 2132
# 처리 중인 프레임: 2132
# ...
# 처리 중인 프레임: 20317
# frame 20317에 bbox 있음: [613.02197265625, 744.0042114257812, 836.8228149414062, 821.3263549804688]
# 처리 중인 프레임: 20318
# frame 20318에 bbox 있음: [612.4774169921875, 745.4987182617188, 836.3162841796875, 821.1029663085938]
# 처리 중인 프레임: 20319
# 이전 프레임: 20318, 다음 프레임: 20320
# 처리 중인 프레임: 20320
# frame 20320에 bbox 있음: [609.8527221679688, 745.4782104492188, 835.6234130859375, 822.8812866210938]
# 처리 중인 프레임: 20321
# 이전 프레임: 20320, 다음 프레임: 20322
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [609.85272217 745.47821045 835.62341309 822.88128662]
# 처리 중인 프레임: 20322
# 이전 프레임: 20321, 다음 프레임: 20323
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 20323
# 이전 프레임: 20322, 다음 프레임: 20324
# 처리 중인 프레임: 20324
# frame 20324에 bbox 있음: [616.8755493164062, 748.6895751953125, 841.2207641601562, 824.9301147460938]
# 처리 중인 프레임: 20325
# frame 20325에 bbox 있음: [615.7005615234375, 752.6976928710938, 845.712158203125, 826.7931518554688]
# 처리 중인 프레임: 20326
# frame 20326에 bbox 있음: [615.75830078125, 752.413330078125, 845.5576782226562, 827.1260375976562]
# 처리 중인 프레임: 20327
# frame 20327에 bbox 있음: [619.760986328125, 753.1563720703125, 846.618408203125, 827.284423828125]
# 처리 중인 프레임: 20328
# frame 20328에 bbox 있음: [618.7327880859375, 754.60546875, 848.640380859375, 828.5390625]
# 처리 중인 프레임: 20329
# frame 20329에 bbox 있음: [624.1699829101562, 756.8655395507812, 851.586181640625, 830.3054809570312]
# 처리 중인 프레임: 20330
# frame 20330에 bbox 있음: [624.2734375, 758.1328125, 856.9446411132812, 830.445556640625]
# 처리 중인 프레임: 20331
# frame 20331에 bbox 있음: [626.8006591796875, 758.786865234375, 861.4876098632812, 833.5843505859375]
# 처리 중인 프레임: 20332
# frame 20332에 bbox 있음: [627.1895141601562, 759.4585571289062, 861.2935791015625, 833.1801147460938]
# 처리 중인 프레임: 20333
# frame 20333에 bbox 있음: [629.4019775390625, 759.9379272460938, 867.1963500976562, 835.0648193359375]
# 가장 높은 점수의 license_number: 259어2415
# Processing car_id: 876.0
# 처리 중인 프레임: 22803
# frame 22803에 bbox 있음: [417.4188537597656, 753.9034423828125, 636.5241088867188, 834.85107421875]
# 처리 중인 프레임: 22804
# frame 22804에 bbox 있음: [417.544921875, 753.8098754882812, 636.3834228515625, 834.9226684570312]
# 처리 중인 프레임: 22805
# frame 22805에 bbox 있음: [414.6500244140625, 752.723388671875, 636.1402587890625, 833.4097290039062]
# 처리 중인 프레임: 22806
# 이전 프레임: 22805, 다음 프레임: 22807
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [414.65002441 752.72338867 636.14025879 833.409729  ]
# 처리 중인 프레임: 22807
# 이전 프레임: 22806, 다음 프레임: 22808
# 처리 중인 프레임: 22808
# frame 22808에 bbox 있음: [410.2891845703125, 751.3247680664062, 636.0847778320312, 833.2897338867188]
# 처리 중인 프레임: 22809
# 이전 프레임: 22808, 다음 프레임: 22810
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [410.28918457 751.32476807 636.08477783 833.28973389]
# 처리 중인 프레임: 22810
# 이전 프레임: 22809, 다음 프레임: 22811
# 처리 중인 프레임: 22811
# frame 22811에 bbox 있음: [408.5565490722656, 758.7387084960938, 635.6923828125, 835.1262817382812]
# 처리 중인 프레임: 22812
# 이전 프레임: 22811, 다음 프레임: 22813
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [408.55654907 758.7387085  635.69238281 835.12628174]
# 처리 중인 프레임: 22813
# 이전 프레임: 22812, 다음 프레임: 22814
# 처리 중인 프레임: 22814
# frame 22814에 bbox 있음: [407.7388916015625, 760.69775390625, 634.36376953125, 839.5391235351562]
# 처리 중인 프레임: 22815
# frame 22815에 bbox 있음: [407.7873229980469, 765.4561157226562, 635.4668579101562, 839.663818359375]
# 처리 중인 프레임: 22816
# frame 22816에 bbox 있음: [407.8938903808594, 765.1686401367188, 635.4100952148438, 839.8709106445312]
# 처리 중인 프레임: 22817
# frame 22817에 bbox 있음: [407.5564270019531, 765.0104370117188, 636.7468872070312, 842.435302734375]
# 처리 중인 프레임: 22818
# frame 22818에 bbox 있음: [407.0348815917969, 763.2295532226562, 636.5286254882812, 842.6145629882812]
# 처리 중인 프레임: 22819
# frame 22819에 bbox 있음: [406.9367370605469, 761.97509765625, 635.790283203125, 844.5882568359375]
# 처리 중인 프레임: 22820
# frame 22820에 bbox 있음: [407.0305480957031, 763.1868896484375, 634.5652465820312, 843.8529052734375]
# 처리 중인 프레임: 22821
# frame 22821에 bbox 있음: [406.08270263671875, 760.7083740234375, 634.8953247070312, 845.7800903320312]
# 처리 중인 프레임: 22822
# frame 22822에 bbox 있음: [406.1574401855469, 760.64501953125, 634.829345703125, 845.8388671875]
# 처리 중인 프레임: 22823
# 이전 프레임: 22822, 다음 프레임: 22824
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [406.15744019 760.64501953 634.8293457  845.83886719]
# 처리 중인 프레임: 22824
# 이전 프레임: 22823, 다음 프레임: 22825
# 처리 중인 프레임: 22825
# frame 22825에 bbox 있음: [407.1162414550781, 763.69775390625, 641.025390625, 845.7813720703125]
# 처리 중인 프레임: 22826
# frame 22826에 bbox 있음: [409.00579833984375, 766.0510864257812, 639.2433471679688, 843.2849731445312]
# 처리 중인 프레임: 22827
# frame 22827에 bbox 있음: [409.56243896484375, 767.3256225585938, 640.1262817382812, 843.7260131835938]
# 처리 중인 프레임: 22828
# 이전 프레임: 22827, 다음 프레임: 22829
# 처리 중인 프레임: 22829
# frame 22829에 bbox 있음: [409.21466064453125, 765.9860229492188, 641.6200561523438, 846.69287109375]
# 처리 중인 프레임: 22830
# frame 22830에 bbox 있음: [408.6854553222656, 768.74658203125, 643.5950927734375, 847.605712890625]
# 처리 중인 프레임: 22831
# frame 22831에 bbox 있음: [409.2879638671875, 768.7591552734375, 645.0286254882812, 849.8851318359375]
# 처리 중인 프레임: 22832
# frame 22832에 bbox 있음: [407.57000732421875, 767.8365478515625, 646.2535400390625, 851.9264526367188]
# 처리 중인 프레임: 22833
# 이전 프레임: 22832, 다음 프레임: 22834
# 처리 중인 프레임: 22834
# frame 22834에 bbox 있음: [405.6169738769531, 767.7528076171875, 646.9182739257812, 853.9273681640625]
# 처리 중인 프레임: 22835
# frame 22835에 bbox 있음: [405.283447265625, 770.3074951171875, 645.2601928710938, 855.6932373046875]
# 처리 중인 프레임: 22836
# frame 22836에 bbox 있음: [405.60498046875, 768.5789794921875, 647.0930786132812, 859.5333251953125]
# 처리 중인 프레임: 22837
# frame 22837에 bbox 있음: [406.5054016113281, 770.326171875, 646.5978393554688, 859.1297607421875]
# 처리 중인 프레임: 22838
# frame 22838에 bbox 있음: [408.3161315917969, 771.80078125, 647.4927978515625, 859.26220703125]
# 처리 중인 프레임: 22839
# 이전 프레임: 22838, 다음 프레임: 22840
# 처리 중인 프레임: 22840
# frame 22840에 bbox 있음: [406.5632629394531, 774.3026733398438, 648.9793090820312, 858.9526977539062]
# 처리 중인 프레임: 22841
# frame 22841에 bbox 있음: [406.2821044921875, 774.666015625, 647.1834106445312, 859.7362670898438]
# 처리 중인 프레임: 22842
# frame 22842에 bbox 있음: [407.7810974121094, 776.7295532226562, 650.0523071289062, 861.2195434570312]
# 처리 중인 프레임: 22843
# frame 22843에 bbox 있음: [408.07855224609375, 778.7836303710938, 653.4057006835938, 861.4920043945312]
# 처리 중인 프레임: 22844
# frame 22844에 bbox 있음: [409.8809509277344, 778.9524536132812, 656.3487548828125, 863.6017456054688]
# 처리 중인 프레임: 22845
# frame 22845에 bbox 있음: [410.85589599609375, 779.0036010742188, 661.2151489257812, 866.6521606445312]
# 처리 중인 프레임: 22846
# frame 22846에 bbox 있음: [411.0843200683594, 779.0262451171875, 661.3153076171875, 866.6136474609375]
# 처리 중인 프레임: 22847
# 이전 프레임: 22846, 다음 프레임: 22848
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [411.08432007 779.02624512 661.31530762 866.61364746]
# 처리 중인 프레임: 22848
# 이전 프레임: 22847, 다음 프레임: 22849
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 22849
# 이전 프레임: 22848, 다음 프레임: 22850
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 22850
# 이전 프레임: 22849, 다음 프레임: 22851
# 처리 중인 프레임: 22851
# frame 22851에 bbox 있음: [416.1684265136719, 790.1782836914062, 672.5048828125, 870.6439819335938]
# 처리 중인 프레임: 22852
# frame 22852에 bbox 있음: [416.2811279296875, 790.1416625976562, 672.5426025390625, 870.7571411132812]
# 처리 중인 프레임: 22853
# 이전 프레임: 22852, 다음 프레임: 22854
# 처리 중인 프레임: 22854
# frame 22854에 bbox 있음: [422.6794128417969, 794.9155883789062, 682.9064331054688, 878.0857543945312]
# 처리 중인 프레임: 22855
# frame 22855에 bbox 있음: [426.9822692871094, 795.8637084960938, 683.9610595703125, 880.1054077148438]
# 처리 중인 프레임: 22856
# 이전 프레임: 22855, 다음 프레임: 22857
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [426.98226929 795.8637085  683.96105957 880.10540771]
# 처리 중인 프레임: 22857
# 이전 프레임: 22856, 다음 프레임: 22858
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 22858
# 이전 프레임: 22857, 다음 프레임: 22859
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 22859
# 이전 프레임: 22858, 다음 프레임: 22860
# 처리 중인 프레임: 22860
# frame 22860에 bbox 있음: [438.7096252441406, 796.1881713867188, 695.7949829101562, 886.3782348632812]
# 처리 중인 프레임: 22861
# frame 22861에 bbox 있음: [440.32342529296875, 799.654052734375, 701.5560302734375, 884.8407592773438]
# 처리 중인 프레임: 22862
# frame 22862에 bbox 있음: [436.6927185058594, 802.2696533203125, 702.8574829101562, 888.636474609375]
# 처리 중인 프레임: 22863
# 이전 프레임: 22862, 다음 프레임: 22864
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [436.69271851 802.26965332 702.85748291 888.63647461]
# 처리 중인 프레임: 22864
# 이전 프레임: 22863, 다음 프레임: 22865
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 22865
# 이전 프레임: 22864, 다음 프레임: 22866
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 22866
# 이전 프레임: 22865, 다음 프레임: 22867
# 처리 중인 프레임: 22867
# frame 22867에 bbox 있음: [456.5115966796875, 801.6884765625, 728.105712890625, 888.1885986328125]
# 처리 중인 프레임: 22868
# frame 22868에 bbox 있음: [460.3919677734375, 804.1547241210938, 733.5851440429688, 889.2434692382812]
# 처리 중인 프레임: 22869
# 이전 프레임: 22868, 다음 프레임: 22870
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [460.39196777 804.15472412 733.58514404 889.24346924]
# 처리 중인 프레임: 22870
# 이전 프레임: 22869, 다음 프레임: 22871
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: []
# 처리 중인 프레임: 22871
# 이전 프레임: 22870, 다음 프레임: 22872
# 처리 중인 프레임: 22872
# frame 22872에 bbox 있음: [479.7916259765625, 806.62744140625, 741.5833740234375, 893.3553466796875]
# 처리 중인 프레임: 22873
# frame 22873에 bbox 있음: [479.7459411621094, 804.2565307617188, 750.6112670898438, 894.9395141601562]
# 처리 중인 프레임: 22874
# 이전 프레임: 22873, 다음 프레임: 22875
# 처리 중인 프레임: 22875
# frame 22875에 bbox 있음: [488.1421813964844, 812.9227294921875, 760.688720703125, 902.745849609375]
# 처리 중인 프레임: 22876
# frame 22876에 bbox 있음: [488.0937194824219, 812.9910278320312, 760.6674194335938, 902.7064819335938]
# 처리 중인 프레임: 22877
# frame 22877에 bbox 있음: [490.3746643066406, 812.7870483398438, 766.429931640625, 904.6536254882812]
# 처리 중인 프레임: 22878
# frame 22878에 bbox 있음: [492.7642822265625, 816.9122314453125, 775.7971801757812, 908.3448486328125]
# 처리 중인 프레임: 22879
# frame 22879에 bbox 있음: [497.7242431640625, 815.2791137695312, 777.7293090820312, 915.633544921875]
# 처리 중인 프레임: 22880
# frame 22880에 bbox 있음: [499.65728759765625, 816.850341796875, 783.66064453125, 913.9156494140625]
# 처리 중인 프레임: 22881
# frame 22881에 bbox 있음: [501.7312316894531, 815.9117431640625, 788.4627685546875, 913.434814453125]
# 처리 중인 프레임: 22882
# 이전 프레임: 22881, 다음 프레임: 22883
# 처리 중인 프레임: 22883
# frame 22883에 bbox 있음: [509.8388671875, 819.6722412109375, 790.755615234375, 915.3126220703125]
# 처리 중인 프레임: 22884
# frame 22884에 bbox 있음: [521.6149291992188, 825.2546997070312, 802.042236328125, 915.7452392578125]
# 처리 중인 프레임: 22885
# frame 22885에 bbox 있음: [526.3114624023438, 822.6434326171875, 810.0523681640625, 917.2532958984375]
# 처리 중인 프레임: 22886
# frame 22886에 bbox 있음: [528.6802978515625, 832.346435546875, 812.71240234375, 921.266845703125]
# 처리 중인 프레임: 22887
# 이전 프레임: 22886, 다음 프레임: 22888
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [528.68029785 832.34643555 812.71240234 921.2668457 ]
# 처리 중인 프레임: 22888
# 이전 프레임: 22887, 다음 프레임: 22889
# 처리 중인 프레임: 22889
# frame 22889에 bbox 있음: [536.9884643554688, 831.2600708007812, 829.5210571289062, 925.5906982421875]
# 처리 중인 프레임: 22890
# 이전 프레임: 22889, 다음 프레임: 22891
# 처리 중인 프레임: 22891
# frame 22891에 bbox 있음: [550.8622436523438, 839.2329711914062, 842.3441772460938, 926.7064819335938]
# 처리 중인 프레임: 22892
# frame 22892에 bbox 있음: [557.5737915039062, 839.9564208984375, 850.2052612304688, 927.988037109375]
# 처리 중인 프레임: 22893
# 이전 프레임: 22892, 다음 프레임: 22894
# 처리 중인 프레임: 22894
# frame 22894에 bbox 있음: [559.49072265625, 841.9031982421875, 854.080322265625, 927.6077270507812]
# 처리 중인 프레임: 22895
# 이전 프레임: 22894, 다음 프레임: 22896
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [559.49072266 841.90319824 854.08032227 927.60772705]
# 처리 중인 프레임: 22896
# 이전 프레임: 22895, 다음 프레임: 22897
# 처리 중인 프레임: 22897
# frame 22897에 bbox 있음: [584.7674560546875, 842.2152099609375, 880.806396484375, 934.6939086914062]
# 처리 중인 프레임: 22898
# frame 22898에 bbox 있음: [583.7354736328125, 841.2718505859375, 888.6992797851562, 936.1966552734375]
# 처리 중인 프레임: 22899
# frame 22899에 bbox 있음: [585.9638671875, 843.06005859375, 891.5982055664062, 937.798095703125]
# 처리 중인 프레임: 22900
# frame 22900에 bbox 있음: [586.805419921875, 843.5693359375, 891.588134765625, 937.0540161132812]
# 처리 중인 프레임: 22901
# 이전 프레임: 22900, 다음 프레임: 22902
# 처리 중인 프레임: 22902
# frame 22902에 bbox 있음: [613.8246459960938, 847.5708618164062, 907.4669189453125, 945.1506958007812]
# 처리 중인 프레임: 22903
# frame 22903에 bbox 있음: [610.7897338867188, 848.9659423828125, 912.4176635742188, 942.9680786132812]
# 처리 중인 프레임: 22904
# frame 22904에 bbox 있음: [612.0474243164062, 845.0797119140625, 924.3484497070312, 949.9962158203125]
# 처리 중인 프레임: 22905
# frame 22905에 bbox 있음: [617.1220092773438, 847.4769287109375, 928.1510009765625, 948.2852783203125]
# 처리 중인 프레임: 22906
# frame 22906에 bbox 있음: [617.1473388671875, 847.4921264648438, 928.1278076171875, 947.9481811523438]
# 처리 중인 프레임: 22907
# 이전 프레임: 22906, 다음 프레임: 22908
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [617.14733887 847.49212646 928.12780762 947.94818115]
# 처리 중인 프레임: 22908
# 이전 프레임: 22907, 다음 프레임: 22909
# 처리 중인 프레임: 22909
# frame 22909에 bbox 있음: [641.8564453125, 854.8341064453125, 951.5372314453125, 957.27099609375]
# 처리 중인 프레임: 22910
# frame 22910에 bbox 있음: [649.6015625, 853.5276489257812, 958.9993286132812, 956.3681030273438]
# 처리 중인 프레임: 22911
# frame 22911에 bbox 있음: [653.6096801757812, 856.306884765625, 965.179931640625, 958.4425659179688]
# 처리 중인 프레임: 22912
# frame 22912에 bbox 있음: [653.5484619140625, 855.8932495117188, 965.1177978515625, 958.6361083984375]
# 처리 중인 프레임: 22913
# 이전 프레임: 22912, 다음 프레임: 22914
# 처리 중인 프레임: 22914
# frame 22914에 bbox 있음: [664.5350341796875, 857.9456176757812, 983.1385498046875, 964.5243530273438]
# 처리 중인 프레임: 22915
# frame 22915에 bbox 있음: [671.2640991210938, 861.53759765625, 987.0668334960938, 963.4072265625]
# 처리 중인 프레임: 22916
# frame 22916에 bbox 있음: [676.3392944335938, 863.4609375, 995.0235595703125, 967.9581298828125]
# 처리 중인 프레임: 22917
# frame 22917에 bbox 있음: [683.7152709960938, 865.3626708984375, 997.6693725585938, 969.5701904296875]
# 처리 중인 프레임: 22918
# frame 22918에 bbox 있음: [683.5850830078125, 865.4959716796875, 997.6190185546875, 969.4623413085938]
# 처리 중인 프레임: 22919
# 이전 프레임: 22918, 다음 프레임: 22920
# 처리 중인 프레임: 22920
# frame 22920에 bbox 있음: [702.3731689453125, 872.4584350585938, 1020.60205078125, 974.4371948242188]
# 처리 중인 프레임: 22921
# frame 22921에 bbox 있음: [707.9544677734375, 874.0746459960938, 1022.235595703125, 976.1537475585938]
# 가장 높은 점수의 license_number: 30바7464
# Processing car_id: 885.0
# 처리 중인 프레임: 22887
# frame 22887에 bbox 있음: [535.5772705078125, 829.2013549804688, 825.9642333984375, 923.5248413085938]
# 가장 높은 점수의 license_number: 30바7464
# Processing car_id: 1031.0
# 처리 중인 프레임: 26496
# frame 26496에 bbox 있음: [248.92149353027344, 712.9714965820312, 492.6978454589844, 810.7754516601562]
# 처리 중인 프레임: 26497
# frame 26497에 bbox 있음: [246.23666381835938, 716.8844604492188, 489.72857666015625, 812.8504028320312]
# 처리 중인 프레임: 26498
# frame 26498에 bbox 있음: [242.71389770507812, 715.9973754882812, 489.16168212890625, 822.480712890625]
# 처리 중인 프레임: 26499
# frame 26499에 bbox 있음: [240.8492889404297, 717.0216064453125, 487.9387512207031, 825.3587036132812]
# 처리 중인 프레임: 26500
# frame 26500에 bbox 있음: [240.93026733398438, 717.1333618164062, 487.84185791015625, 825.3168334960938]
# 처리 중인 프레임: 26501
# 이전 프레임: 26500, 다음 프레임: 26502
# 처리 중인 프레임: 26502
# frame 26502에 bbox 있음: [234.80813598632812, 727.6631469726562, 488.4480285644531, 832.2154541015625]
# 처리 중인 프레임: 26503
# 이전 프레임: 26502, 다음 프레임: 26504
# 처리 중인 프레임: 26504
# frame 26504에 bbox 있음: [233.50543212890625, 739.3544311523438, 490.259521484375, 833.7593994140625]
# 가장 높은 점수의 license_number: 86가9842
# Processing car_id: 1033.0
# 처리 중인 프레임: 26505
# frame 26505에 bbox 있음: [234.9027099609375, 740.8465576171875, 493.2679138183594, 839.5491943359375]
# 처리 중인 프레임: 26506
# 이전 프레임: 26505, 다음 프레임: 26507
# 처리 중인 프레임: 26507
# frame 26507에 bbox 있음: [234.99874877929688, 744.8551025390625, 494.5665283203125, 841.0389404296875]
# 처리 중인 프레임: 26508
# frame 26508에 bbox 있음: [236.85992431640625, 747.7818603515625, 495.563720703125, 845.0625]
# 처리 중인 프레임: 26509
# frame 26509에 bbox 있음: [239.44065856933594, 745.9281005859375, 501.1421813964844, 848.1692504882812]
# 처리 중인 프레임: 26510
# frame 26510에 bbox 있음: [240.117919921875, 740.8998413085938, 507.5606994628906, 848.4664306640625]
# 가장 높은 점수의 license_number: 86가9842
# Interpolation 완료 후 test2.csv 저장 완료.

# %%
import pandas as pd
import numpy as np

# test.csv 파일을 읽어옵니다.
df = pd.read_csv('test.csv')

# 조건에 맞는 데이터만 필터링합니다.
df = df[(df['license_number'] != 'unknown') & (df['license_number_score'].notna())]

# car_id 별로 데이터를 그룹화하고, 프레임 번호에서 빈 공백을 전부 보정합니다.
def interpolate_license_numbers(group):
    frames = group['frame_nmr'].values
    scores = group['license_number_score'].values
    
    # license_plate_bbox를 문자열에서 리스트로 변환 (공백으로 구분)
    license_plate_bboxes = group['license_plate_bbox'].apply(
        lambda x: list(map(float, x.strip('[]').split()))  # 공백으로 나누도록 수정
    ).values
    
    # 프레임을 0에서부터 연속된 정수로 만든 후, 보간(interpolation)을 합니다.
    full_frames = np.arange(frames.min(), frames.max() + 1)
    interpolated_df = pd.DataFrame({'frame_nmr': full_frames})

    # 점수 데이터 보간
    interpolated_df['license_number_score'] = np.interp(full_frames, frames, scores)
    
    # bbox 보간은 하지 않고 그대로 가져옵니다.
    license_plate_bboxes_dict = dict(zip(frames, license_plate_bboxes))
    
    # 프레임 간 공백이 있을 때, 그 사이의 bbox를 보간하여 채웁니다.
    interpolated_bboxes = []
    for frame in full_frames:
        print(f"처리 중인 프레임: {frame}")  # 디버깅: 현재 프레임을 출력
        if frame in license_plate_bboxes_dict:
            print(f"frame {frame}에 bbox 있음: {license_plate_bboxes_dict[frame]}")  # 디버깅: bbox 값 출력
            interpolated_bboxes.append(license_plate_bboxes_dict[frame])
        else:
            # 앞뒤 프레임의 bbox 차이를 계산하여 보간
            prev_frame = full_frames[full_frames < frame].max() if (full_frames < frame).any() else None
            next_frame = full_frames[full_frames > frame].min() if frame < full_frames.max() else None
            print(f"이전 프레임: {prev_frame}, 다음 프레임: {next_frame}")  # 디버깅: 이전 및 다음 프레임 출력
            
            # prev_frame이 없으면 그 다음 프레임을 사용하도록 수정
            if prev_frame is None:
                prev_frame = next_frame  # 이전 프레임이 없으면 다음 프레임으로 대체
                print(f"prev_frame이 없으므로 next_frame({next_frame})을 prev_frame로 사용")  # 디버깅

            prev_bbox = np.array(license_plate_bboxes_dict.get(prev_frame, None))  # 수정: .get() 사용하여 KeyError 방지

            # prev_bbox가 없으면 예외 처리 (빈 bbox로 처리할 수 없음)
            if prev_bbox is None:
                print(f"Error: frame {frame}에 대한 bbox를 찾을 수 없습니다.")
                prev_bbox = [0, 0, 0, 0]  # 빈 bbox로 대체 (기본값 설정)
                print(f"prev_bbox를 기본값 [0, 0, 0, 0]으로 대체: {prev_bbox}")

            print(f"prev_bbox: {prev_bbox}")  # 디버깅: prev_bbox 값 출력
            if next_frame is not None and next_frame in license_plate_bboxes_dict:
                next_bbox = np.array(license_plate_bboxes_dict[next_frame])
                print(f"next_bbox: {next_bbox}")  # 디버깅: next_bbox 값 출력
                
                # 각 컴포넌트별 선형 보간 (x1, y1, x2, y2)
                interpolated_bbox = []
                for prev_val, next_val in zip(prev_bbox, next_bbox):
                    ratio = (frame - prev_frame) / (next_frame - prev_frame)
                    interpolated_bbox.append(prev_val + ratio * (next_val - prev_val))
            else:
                # next_frame이 없다면 이전 프레임의 bbox를 그대로 사용
                interpolated_bbox = prev_bbox
                print(f"bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: {prev_bbox}")  # 디버깅: 사용된 bbox 출력
                
            interpolated_bboxes.append(interpolated_bbox)  # tolist()는 필요 없음
    
    interpolated_df['license_plate_bbox'] = interpolated_bboxes
    
    # 가장 높은 점수의 license_number를 찾습니다.
    best_license_number = group.loc[group['license_number_score'].idxmax()]['license_number']
    print(f"가장 높은 점수의 license_number: {best_license_number}")  # 디버깅: 최고 점수의 license_number 출력

    # 모든 프레임에 대해 동일한 license_number를 할당합니다.
    interpolated_df['license_number'] = best_license_number
    
    return interpolated_df

# 각 car_id 별로 보간(interpolation)을 수행합니다.
interpolated_df_list = []
for car_id, group in df.groupby('car_id'):
    print(f"Processing car_id: {car_id}")  # 디버깅: 현재 car_id 출력
    interpolated_group = interpolate_license_numbers(group)
    interpolated_group['car_id'] = car_id  # car_id 추가
    interpolated_df_list.append(interpolated_group)

# 모든 car_id에 대한 보간된 데이터프레임을 합칩니다.
final_df = pd.concat(interpolated_df_list)

# 결과를 test2.csv 파일로 저장합니다.
final_df.to_csv('test-interpolated.csv', index=False)

print("Interpolation 완료 후 test2.csv 저장 완료.")
# Out:
# Processing car_id: 27.0
# 처리 중인 프레임: 462
# frame 462에 bbox 있음: [668.3450927734375, 348.2243347167969, 834.7011108398438, 415.2502746582031]
# 처리 중인 프레임: 463
# frame 463에 bbox 있음: [662.1337280273438, 348.9031677246094, 834.8660888671875, 415.0970764160156]
# 처리 중인 프레임: 464
# frame 464에 bbox 있음: [657.94921875, 348.33380126953125, 829.7493896484375, 413.2100830078125]
# 처리 중인 프레임: 465
# frame 465에 bbox 있음: [657.9093627929688, 348.2719421386719, 829.7589721679688, 413.28472900390625]
# 처리 중인 프레임: 466
# 이전 프레임: 465, 다음 프레임: 467
# prev_bbox: [657.90936279 348.27194214 829.75897217 413.284729  ]
# next_bbox: [648.50012207 344.96594238 826.86663818 412.18643188]
# 처리 중인 프레임: 467
# frame 467에 bbox 있음: [648.5001220703125, 344.9659423828125, 826.8666381835938, 412.1864318847656]
# 처리 중인 프레임: 468
# frame 468에 bbox 있음: [643.6536865234375, 343.0175476074219, 823.000732421875, 411.48773193359375]
# 처리 중인 프레임: 469
# frame 469에 bbox 있음: [640.4811401367188, 342.03387451171875, 820.3818969726562, 410.9256591796875]
# 처리 중인 프레임: 470
# frame 470에 bbox 있음: [637.4917602539062, 341.89654541015625, 821.1600952148438, 410.7203063964844]
# 처리 중인 프레임: 471
# frame 471에 bbox 있음: [637.6062622070312, 341.87017822265625, 821.0687866210938, 410.6767272949219]
# 처리 중인 프레임: 472
# frame 472에 bbox 있음: [635.8617553710938, 342.0754699707031, 820.9713745117188, 411.2620544433594]
# 처리 중인 프레임: 473
# frame 473에 bbox 있음: [634.5964965820312, 342.75762939453125, 822.0730590820312, 411.6666259765625]
# 처리 중인 프레임: 474
# frame 474에 bbox 있음: [633.0604248046875, 342.5303955078125, 821.6687622070312, 412.30181884765625]
# 처리 중인 프레임: 475
# frame 475에 bbox 있음: [631.6528930664062, 343.6943054199219, 821.39501953125, 412.24688720703125]
# 처리 중인 프레임: 476
# frame 476에 bbox 있음: [632.379150390625, 345.6158142089844, 822.1783447265625, 413.04632568359375]
# 처리 중인 프레임: 477
# frame 477에 bbox 있음: [630.8606567382812, 344.55267333984375, 822.0125122070312, 412.63604736328125]
# 처리 중인 프레임: 478
# frame 478에 bbox 있음: [631.6767578125, 346.453857421875, 821.8425903320312, 413.822021484375]
# 처리 중인 프레임: 479
# frame 479에 bbox 있음: [631.6937866210938, 347.2265625, 821.3435668945312, 413.9792175292969]
# 처리 중인 프레임: 480
# frame 480에 bbox 있음: [631.27392578125, 347.77838134765625, 820.1694946289062, 415.7867736816406]
# 처리 중인 프레임: 481
# frame 481에 bbox 있음: [631.2960815429688, 348.58111572265625, 819.9262084960938, 416.94921875]
# 처리 중인 프레임: 482
# frame 482에 bbox 있음: [630.6591796875, 348.90838623046875, 820.0433349609375, 417.7229919433594]
# 처리 중인 프레임: 483
# frame 483에 bbox 있음: [630.670166015625, 348.91290283203125, 820.0770874023438, 417.69189453125]
# 처리 중인 프레임: 484
# frame 484에 bbox 있음: [630.9505004882812, 348.86627197265625, 819.9488525390625, 417.947021484375]
# 처리 중인 프레임: 485
# frame 485에 bbox 있음: [631.17333984375, 348.1040954589844, 819.3515625, 418.8490905761719]
# 처리 중인 프레임: 486
# frame 486에 bbox 있음: [632.1163330078125, 349.6217956542969, 821.1362915039062, 419.1820983886719]
# 처리 중인 프레임: 487
# frame 487에 bbox 있음: [630.8106689453125, 346.10589599609375, 822.986083984375, 422.65167236328125]
# 가장 높은 점수의 license_number: 50루7604
# Processing car_id: 39.0
# 처리 중인 프레임: 515
# frame 515에 bbox 있음: [633.7775268554688, 363.9963684082031, 825.3704833984375, 436.6414489746094]
# 처리 중인 프레임: 516
# frame 516에 bbox 있음: [632.994873046875, 368.3365173339844, 827.2988891601562, 439.74224853515625]
# 처리 중인 프레임: 517
# frame 517에 bbox 있음: [630.1876831054688, 371.7996826171875, 827.233154296875, 442.7339172363281]
# 처리 중인 프레임: 518
# frame 518에 bbox 있음: [634.7947998046875, 377.34625244140625, 831.87158203125, 448.8736572265625]
# 처리 중인 프레임: 519
# frame 519에 bbox 있음: [634.2460327148438, 376.76861572265625, 832.4310302734375, 449.3367919921875]
# 처리 중인 프레임: 520
# 이전 프레임: 519, 다음 프레임: 521
# prev_bbox: [634.24603271 376.76861572 832.43103027 449.33679199]
# next_bbox: [638.12628174 384.35760498 835.27868652 459.93978882]
# 처리 중인 프레임: 521
# frame 521에 bbox 있음: [638.1262817382812, 384.35760498046875, 835.2786865234375, 459.9397888183594]
# 처리 중인 프레임: 522
# frame 522에 bbox 있음: [640.5726928710938, 391.6814880371094, 835.6624145507812, 466.1069030761719]
# 처리 중인 프레임: 523
# frame 523에 bbox 있음: [642.5643920898438, 395.41387939453125, 836.9103393554688, 474.07415771484375]
# 처리 중인 프레임: 524
# frame 524에 bbox 있음: [641.717529296875, 407.57391357421875, 840.0218505859375, 481.7701721191406]
# 처리 중인 프레임: 525
# frame 525에 bbox 있음: [641.81494140625, 408.200439453125, 839.8320922851562, 481.1712646484375]
# 처리 중인 프레임: 526
# frame 526에 bbox 있음: [643.0537719726562, 413.1365661621094, 844.2313842773438, 487.58880615234375]
# 처리 중인 프레임: 527
# frame 527에 bbox 있음: [643.1741333007812, 419.3653564453125, 845.3375854492188, 493.37567138671875]
# 처리 중인 프레임: 528
# frame 528에 bbox 있음: [648.3643798828125, 431.1602783203125, 847.2689208984375, 503.32489013671875]
# 처리 중인 프레임: 529
# 이전 프레임: 528, 다음 프레임: 530
# prev_bbox: [648.36437988 431.16027832 847.2689209  503.32489014]
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: [648.36437988 431.16027832 847.2689209  503.32489014]
# 처리 중인 프레임: 530
# 이전 프레임: 529, 다음 프레임: 531
# prev_bbox: None
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: None
# 처리 중인 프레임: 531
# 이전 프레임: 530, 다음 프레임: 532
# prev_bbox: None
# bbox 보간을 할 수 없으므로 prev_frame의 bbox 사용: None
# 처리 중인 프레임: 532
# 이전 프레임: 531, 다음 프레임: 533
# prev_bbox: None
# next_bbox: [657.90344238 481.83273315 857.04510498 559.9364624 ]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 88
#      86 for car_id, group in df.groupby('car_id'):
#      87     print(f"Processing car_id: {car_id}")  # 디버깅: 현재 car_id 출력
# ---> 88     interpolated_group = interpolate_license_numbers(group)
#      89     interpolated_group['car_id'] = car_id  # car_id 추가
#      90     interpolated_df_list.append(interpolated_group)
#
# Cell In[6], line 63, in interpolate_license_numbers(group)
#      61 # 각 컴포넌트별 선형 보간 (x1, y1, x2, y2)
#      62 interpolated_bbox = []
# ---> 63 for prev_val, next_val in zip(prev_bbox, next_bbox):
#      64     ratio = (frame - prev_frame) / (next_frame - prev_frame)
#      65     interpolated_bbox.append(prev_val + ratio * (next_val - prev_val))
#
# TypeError: iteration over a 0-d array

# %%
import numpy as np

def linear_interpolation(prev_bbox, next_bbox, ratio):
    """
    선형 보간을 사용하여 두 바운딩 박스의 중간 값을 계산하는 함수.
    
    :param prev_bbox: 이전 바운딩 박스 [x1, y1, x2, y2]
    :param next_bbox: 다음 바운딩 박스 [x3, y3, x4, y4]
    :param ratio: 보간 비율 (0 <= ratio <= 1). ratio가 0이면 prev_bbox, 1이면 next_bbox에 가까워짐.
    
    :return: 보간된 바운딩 박스 [x1', y1', x2', y2']
    """
    prev_bbox = np.array(prev_bbox)
    next_bbox = np.array(next_bbox)
    
    # 각 컴포넌트별로 선형 보간
    interpolated_bbox = prev_bbox + ratio * (next_bbox - prev_bbox)
    
    return interpolated_bbox.tolist()

# 예시 사용
prev_bbox = [100, 150, 200, 250]  # 이전 바운딩 박스 (x1, y1, x2, y2)
next_bbox = [120, 170, 220, 270]  # 다음 바운딩 박스 (x1, y1, x2, y2)

# 보간 비율 (0.5는 중간 값)
ratio = 0.5

interpolated_bbox = linear_interpolation(prev_bbox, next_bbox, ratio)

print(f"보간된 바운딩 박스: {interpolated_bbox}")
# Out:
# 보간된 바운딩 박스: [110.0, 160.0, 210.0, 260.0]

# %%
import pandas as pd

# test.csv 읽기
df = pd.read_csv('test.csv')

# bbox 열의 공백을 쉼표로 변경
df['car_bbox'] = df['car_bbox'].apply(lambda x: x.replace(' ', ',') if isinstance(x, str) else x)
df['license_plate_bbox'] = df['license_plate_bbox'].apply(lambda x: x.replace(' ', ',') if isinstance(x, str) else x)

# 변경된 내용을 저장
df.to_csv('test.csv', index=False)

print("공백이 쉼표로 변경된 파일이 'test_updated.csv'로 저장되었습니다.")
# Out:
# 공백이 쉼표로 변경된 파일이 'test_updated.csv'로 저장되었습니다.

# %%
import pandas as pd
import numpy as np

def linear_interpolation(prev_bbox, next_bbox, ratio):
    """
    선형 보간을 사용하여 두 바운딩 박스의 중간 값을 계산하는 함수.
    
    :param prev_bbox: 이전 바운딩 박스 [x1, y1, x2, y2]
    :param next_bbox: 다음 바운딩 박스 [x3, y3, x4, y4]
    :param ratio: 보간 비율 (0 <= ratio <= 1). ratio가 0이면 prev_bbox, 1이면 next_bbox에 가까워짐.
    
    :return: 보간된 바운딩 박스 [x1', y1', x2', y2']
    """
    prev_bbox = np.array(prev_bbox)
    next_bbox = np.array(next_bbox)
    
    # 각 컴포넌트별로 선형 보간
    interpolated_bbox = prev_bbox + ratio * (next_bbox - prev_bbox)
    
    return interpolated_bbox.tolist()

def find_nearest_frames(df, missing_idx):
    """
    주어진 프레임에서 앞뒤로 가장 가까운 데이터가 있는 프레임을 찾는 함수.
    
    :param df: 프레임별 바운딩 박스 데이터가 포함된 DataFrame.
    :param missing_idx: 공백이 있는 프레임의 인덱스.
    :return: (prev_frame, next_frame) 데이터 튜플
    """
    prev_idx = missing_idx - 1
    next_idx = missing_idx + 1
    
    # 이전 프레임 찾기
    while prev_idx >= 0 and pd.isnull(df.iloc[prev_idx]['bbox']):
        prev_idx -= 1

    # 다음 프레임 찾기
    while next_idx < len(df) and pd.isnull(df.iloc[next_idx]['bbox']):
        next_idx += 1

    # 이전과 다음 프레임이 모두 유효하면 반환
    if prev_idx >= 0 and next_idx < len(df):
        return df.iloc[prev_idx], df.iloc[next_idx]
    
    return None, None

def interpolate_with_fallback(df):
    """
    공백이 존재하면 선형 보간을 수행하고, 이전/다음 프레임을 찾는 방식으로 보간하는 함수.
    
    :param df: 프레임별 바운딩 박스 데이터가 포함된 DataFrame.
    :return: 보간된 DataFrame.
    """
    interpolated_df = []
    
    for i in range(len(df)):
        current_frame = df.iloc[i]
        
        if pd.notnull(current_frame['license_plate_bbox']):
            interpolated_df.append(current_frame)
        else:
            # 공백인 경우
            prev_frame, next_frame = find_nearest_frames(df, i)
            
            if prev_frame is not None and next_frame is not None:
                prev_bbox = [float(coord) for coord in prev_frame['license_plate_bbox'].split()]
                next_bbox = [float(coord) for coord in next_frame['license_plate_bbox'].split()]
                
                # 프레임 비율 계산 (현재 프레임은 prev_frame과 next_frame 사이의 비율로 보간)
                ratio = (df.iloc[i]['frame'] - prev_frame['frame']) / (next_frame['frame'] - prev_frame['frame'])
                
                # 선형 보간 적용
                interpolated_bbox = linear_interpolation(prev_bbox, next_bbox, ratio)
                
                interpolated_frame = current_frame.copy()
                interpolated_frame['license_plate_bbox'] = ' '.join(map(str, interpolated_bbox))
                
                interpolated_df.append(interpolated_frame)
            else:
                # 보간할 프레임이 없다면 그냥 이전 값 혹은 기본값을 사용
                interpolated_df.append(current_frame)
    
    return pd.DataFrame(interpolated_df)

# test.csv 읽기
df = pd.read_csv('test.csv')

# 보간 수행
interpolated_df = interpolate_with_fallback(df)

# 보간 결과 확인
print(interpolated_df)
# Out:
#       frame_nmr  car_id                                           car_bbox  \
# 0            35     1.0  [992.7207367496932,287.6132315221208,1183.2023...
# 1            36     1.0  [993.8111691922744,287.34976026549236,1183.824...
# 2            37     1.0  [994.3410897175274,286.910509994849,1184.86459...
# 3            38     1.0  [994.0024062193995,286.57328886217744,1184.582...
# 4            39     1.0  [993.9555603670332,286.34476159251597,1184.618...
# ...         ...     ...                                                ...
# 7597      26536  1035.0  [53.05590960120037,136.28016010411216,1186.713...
# 7598      26540  1035.0  [66.35668607545529,98.04636390104815,1309.0611...
# 7599      26543  1037.0  [61.076915877627016,111.66588419240122,1388.32...
# 7600      26568  1042.0  [543.3720104844144,41.95709695758876,1922.4028...
# 7601      26569  1042.0  [470.7683601318711,31.61851219856902,1898.7193...
#
#                                      license_plate_bbox  \
# 0     [1063.045166015625,364.34967041015625,1114.748...
# 1     [1058.9898681640625,363.84625244140625,1115.76...
# 2     [1058.181884765625,363.3417663574219,1115.2979...
# 3     [1056.0587158203125,363.21014404296875,1115.49...
# 4     [1056.0985107421875,363.1952819824219,1115.495...
# ...                                                 ...
# 7597  [482.81561279296875,816.39990234375,833.940551...
# 7598  [615.7827758789062,840.476806640625,994.127929...
# 7599  [685.7285766601562,853.5728759765625,1067.0895...
# 7600  [835.8689575195312,442.67645263671875,1022.745...
# 7601  [862.1010131835938,411.5508728027344,1021.3049...
#
#       license_plate_bbox_score license_number  license_number_score
# 0                     0.252066        Unknown                   NaN
# 1                     0.357845        Unknown                   NaN
# 2                     0.316138        Unknown                   NaN
# 3                     0.380504        Unknown                   NaN
# 4                     0.382129        Unknown                   NaN
# ...                        ...            ...                   ...
# 7597                  0.723262        Unknown                   NaN
# 7598                  0.468464        Unknown                   NaN
# 7599                  0.423285        Unknown                   NaN
# 7600                  0.535399        Unknown                   NaN
# 7601                  0.646057        Unknown                   NaN
#
# [7602 rows x 7 columns]

# %%
def replace_license_number_with_max_confidence(df):
    """
    각 car_id 그룹에서 confidence가 가장 높은 번호판 넘버로 replace하는 함수.
    
    :param df: DataFrame containing car_id, license_number, confidence columns.
    :return: 전처리된 DataFrame.
    """
    processed_groups = []

    for car_id, group in df.groupby('car_id'):
        # "Unknown"이나 confidence가 None인 행 제외
        valid_group = group[(group['license_number'] != "Unknown") & (group['license_number_score'].notnull())]
        
        if not valid_group.empty:
            # confidence가 가장 높은 번호판 넘버 선택
            best_row = valid_group.loc[valid_group['license_number_score'].idxmax()]
            best_license_plate_number = best_row['license_number']
            
            # 해당 번호판 넘버로 전체 그룹 replace
            group['license_number'] = best_license_plate_number

        processed_groups.append(group)

    # 모든 그룹 합치기
    return pd.concat(processed_groups)

# CSV 파일 읽기
df = pd.read_csv('test.csv')

# 전처리 수행
processed_df = replace_license_number_with_max_confidence(df)

# 결과를 새로운 CSV로 저장
processed_df.to_csv('processed_test.csv', index=False)

print("번호판 넘버가 전처리된 데이터가 'processed_test.csv'에 저장되었습니다.")
# Out:
# 번호판 넘버가 전처리된 데이터가 'processed_test.csv'에 저장되었습니다.
